# %% [markdown]
# # Explore Gulf of Mexico SSTs during the 2020 hurricane season
# ### Search by user-defined geographic region of interest using shapefiles
#
# The evolution of sea surface temperature (SST) anomalies in the Gulf of Mexico before, during, and after Tropical Cyclones can be explored using NASA remote sensing data, such as the MODIS Aqua SST dataset. An ocean response can often be seen in the wake of hurricane tracks, with cold wakes, or areas of cooler water, along or to the right of hurricane tracks in association with wind-induced water column mixing that brings cooler waters at depth to the surface. These cold signatures are generally patchy and spatially confined. This notebook walks through the discovery, download, and plotting of remote sensing ocean SST level 2 (L2) data over a geographic region of interest defined by the user (through the use of common GIS files such as .shp) during the 2020 hurricane season.
#
# As NASA Earthdata transitions to the Earthdata Cloud, it will be common for some data to exist in a traditional on-premise storage system, accessed by direct download to a local environment, while other data will have migrated to the cloud system. This need to access and customize data from the Earthdata Cloud, and work with it locally is described in this notebook. This access workflow of cloud-based data and downloding to local environment for further analysis or use is presented in the Introduction (Part I) of the workshop, and described again here:
#
# <img align="center"
#      src="shpSearch_downloadLocal_diagram.png">
#
# --> insert final data figure here <--
#
# *Note: In this example we are using a shape file to search on ocean remote sensing data, although one can do this type of search on any Earthdata (DAAC) data. For example, of particular interest could be using shape files to search on terrestrial hydrology data (e.g watersheds), globally (depending on data availability of course).*
#
# *Note: Here we show a programmatic way of completing this type of workflow, but this can also be accomplished through the Earthdata Search user interface. For a video tutorial on how to do this, please see https://www.youtube.com/watch?v=d1BR8w3u0dI&list=PLDWiCz1Ka4kSbqkoeOcPXGAv0gp8OS1Ah&index=7, and disregard the comments about 'UAT' (test environment), as this capability has since become operational. Use https://search.earthdata.nasa.gov/ and follow the rest of the steps in the video tutorial. Search by HUC (hydrologic unit code) capability is also available, if you are working with data over the United States. A video tutorial on how to search by HUC in Earthdata Search is available here: https://www.youtube.com/watch?v=8TLJOFe7XPw&list=PLDWiCz1Ka4kSbqkoeOcPXGAv0gp8OS1Ah&index=6*
#
# #### Learning Objectives:
# 0. Earthdata Login Authentication (for download access from Earthdata data archive)
# 1. Search CMR for collection and granule IDs, using the collection shortname and provider
# 2. Download a file from the PO.DAAC (Earthdata) cloud archive to local computer and preview the data
# 3. Search a collection by user-provided shapefile (ESRI shp) and temporal range
# 4. Donwload the first file (from the PO.DAAC cloud archive to local computer) and preview subset
# 4. Download all data (from the PO.DAAC cloud archive to local computer) based on shp and time search criteria
#
# -----

# %% [markdown]
# ## First, import needed packages and libraries

# %%
# %matplotlib inline

from os.path import join, expanduser, basename
from urllib import request, parse
import requests
import shutil
from http.cookiejar import CookieJar
from getpass import getpass
from netrc import netrc
import pprint
from platform import system

import xarray as xr
import matplotlib.pyplot as plt
import cartopy.crs as ccrs

# %% [markdown]
# ## Earthdata Login Authentication
#
# An Earthdata Login account is required to access data, as well as discover restricted data, from the NASA Earthdata system. Please visit https://urs.earthdata.nasa.gov to register and manage your Earthdata Login account. This account is free to create and only takes a moment to set up.
#
# At this point in time (as we are still transitioning to a cloud environment), in order to access data from the Earthdata Cloud, you need special, early access, persmissions. For the workshop today, you have already been added to the list and the Earthdata login you provided prior to the workshop has been granted this access.

# %% [markdown]
# The `setup_earthdata_login_auth` function will allow Python scripts to log into any Earthdata Login application programmatically.  To avoid being prompted for
# credentials every time you run and also allow clients such as curl to log in, you can add the following
# to a `.netrc` (`_netrc` on Windows) file in your home directory:
#
# ```
# machine urs.earthdata.nasa.gov
#     login <your username>
#     password <your password>
# ```
#
# Make sure that this file is only readable by the current user or you will receive an error stating
# "netrc access too permissive."
#
# `$ chmod 0600 ~/.netrc`

# %%
TOKEN_DATA = ("<token>"
              "<username>%s</username>"
              "<password>%s</password>"
              "<client_id>PODAAC CMR Client</client_id>"
              "<user_ip_address>%s</user_ip_address>"
              "</token>")


def setup_cmr_token_auth(endpoint: str='cmr.earthdata.nasa.gov'):
    ip = requests.get("https://ipinfo.io/ip").text.strip()
    return requests.post(
        url="https://%s/legacy-services/rest/tokens" % endpoint,
        data=TOKEN_DATA % (input("Username: "), getpass("Password: "), ip),
        headers={'Content-Type': 'application/xml', 'Accept': 'application/json'}
    ).json()['token']['id']


def setup_earthdata_login_auth(endpoint: str='urs.earthdata.nasa.gov'):
    netrc_name = "_netrc" if system()=="Windows" else ".netrc"
    try:
        username, _, password = netrc(file=join(expanduser('~'), netrc_name)).authenticators(endpoint)
    except (FileNotFoundError, TypeError):
        print('Please provide your Earthdata Login credentials for access.')
        print('Your info will only be passed to %s and will not be exposed in Jupyter.' % (endpoint))
        username = input('Username: ')
        password = getpass('Password: ')
    manager = request.HTTPPasswordMgrWithDefaultRealm()
    manager.add_password(None, endpoint, username, password)
    auth = request.HTTPBasicAuthHandler(manager)
    jar = CookieJar()
    processor = request.HTTPCookieProcessor(jar)
    opener = request.build_opener(auth, processor)
    request.install_opener(opener)


# Get your authentication token for searching restricted records in the CMR:
_token = setup_cmr_token_auth(endpoint="cmr.earthdata.nasa.gov")

# Start authenticated session with URS to allow restricted data downloads:
setup_earthdata_login_auth(endpoint="urs.earthdata.nasa.gov")
# Out:
# Username:  apbarret
# Password:  ·············

# %% [markdown]
# -----------
# ### Explore data availability using the Common Metadata Repository
# The Common Metadata Repository (CMR) is a robust metadata system that catalogs Earth Science data and associated service metadata records. CMR supports data search and discovery through an Application Programming Interface, or API, enabling reproducible data product and data file searches using a number of helpful variables, including geographic area, keyword, provider, and time.
#
# General CMR API documentation: https://cmr.earthdata.nasa.gov/search/site/docs/search/api.html

# %% [markdown]
# ## 1. Identify a data collection of interest
#
# Data sets are selected by data set IDs (e.g. `MODIS_T-JPL-L2P-v2019.0`). In the CMR API documentation, a data set id is referred to as a "short name". These short names are located at the top of each NSIDC data set landing page in gray above the full title:
#
# - go to https://search.earthdata.nasa.gov/search and type *POCLOUD* in the search box (which is the PO.DAAC data provider for cloud-based Pathfinder datasets in a restricted operational cloud environment). Click on the (i) next to the data collection of interest; the `shortname` is the subheader name below the main full data collection name.
#
# <img align="center"
#      src="EDS_info.png">
#
# ShortName:
# <img align="center"
#      src="EDS_shortname.png">

# %% [markdown]
# In this tutorial we will be using the **MODIS-Terra SST L2 collection**, with the shortname: `MODIS_T-JPL-L2P-v2019.0`. Data from our collection of interest can be obtained from the PO.DAAC (Earthdata) cloud archive.
#
# ### Search by dataset shortname and provider
#
# To search Earthdata from this notebook, we can use the following code with key words that describe our dataset (also knows as a **collection**). This snippet of Python code uses the `requests` module to get collection metadata from the CMR, with our dataset of interset *shortname* and *provider* as search criteria (parameters). In subsequet notebooks (demos), this functionality is hidden in a package called `tutorial_helper_functions` for ease of use. For now, this code snippet will help us understand how the request is made:

# %%
modis_coll = requests.get(
    url="https://cmr.earthdata.nasa.gov/search/collections.umm_json",    # CMR API url
    params={'ShortName': "MODIS_T-JPL-L2P-v2019.0",      # dataset collection shortname
            'provider': "POCLOUD",      # data provider
            'token': _token},
).json()

modis_coll['items'][0]['meta']   # print collection metadata
# Out:
# {'revision-id': 3,
#  'deleted': False,
#  'format': 'application/vnd.nasa.cmr.umm+json',
#  'provider-id': 'POCLOUD',
#  'user-id': 'chen5510',
#  'has-formats': True,
#  'associations': {'services': ['S1962070864-POCLOUD']},
#  'has-spatial-subsetting': False,
#  'native-id': 'GHRSST+Level+2P+Global+Sea+Surface+Skin+Temperature+from+the+Moderate+Resolution+Imaging+Spectroradiometer+(MODIS)+on+the+NASA+Terra+satellite+(GDS2)',
#  'has-transforms': False,
#  'has-variables': False,
#  'concept-id': 'C1940475563-POCLOUD',
#  'revision-date': '2020-09-17T14:28:22.903Z',
#  'granule-count': 0,
#  'has-temporal-subsetting': False,
#  'concept-type': 'collection'}

# %% [markdown]
# Based on the metadata retrieved above, we now know the collection ID (*concept-id*) is `C1940475563-POCLOUD`

# %% [markdown]
# To **retrieve the *granule (file)* metadata** from the CMR:

# %%
modis_gran = requests.get(
    url="https://cmr.earthdata.nasa.gov/search/granules.umm_json", 
    params={'ShortName': "MODIS_T-JPL-L2P-v2019.0", 
            'provider': "POCLOUD",
            'token': _token, },
).json()

modis_gran['items'][0]['meta']
# Out:
# {'concept-type': 'granule',
#  'concept-id': 'G1967602341-POCLOUD',
#  'revision-id': 1,
#  'native-id': '20000227000005-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0',
#  'provider-id': 'POCLOUD',
#  'format': 'application/vnd.nasa.cmr.umm+json',
#  'revision-date': '2020-11-16T21:53:54.241Z'}

# %% [markdown]
# In this case, the metadata tells us that the the granule ID is `G1967602341-POCLOUD`, among other information.

# %% [markdown]
# ## 2. Download a granule & preview data

# %% [markdown]
# ### Access & preview the data - get a quick feel for what the data looks like
# Here is how to list the URLs needed to access the data:

# %%
modis_gran['items'][0]['umm']['RelatedUrls']
# Out:
# [{'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MODIS_T-JPL-L2P-v2019.0/20000227000005-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc.md5',
#   'Description': 'Download 20000227000005-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc.md5',
#   'Type': 'EXTENDED METADATA'},
#  {'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20000227000005-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#   'Description': 'Download 20000227000005-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#   'Type': 'GET DATA'},
#  {'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MODIS_T-JPL-L2P-v2019.0/20000227000005-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.cmr.json',
#   'Description': 'Download 20000227000005-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.cmr.json',
#   'Type': 'EXTENDED METADATA'},
#  {'URL': 'https://archive.podaac.earthdata.nasa.gov/s3credentials',
#   'Description': 'api endpoint to retrieve temporary credentials valid for same-region direct s3 access',
#   'Type': 'VIEW RELATED INFORMATION'},
#  {'URL': 'https://opendap.earthdata.nasa.gov/providers/POCLOUD/collections/GHRSST%20Level%202P%20Global%20Sea%20Surface%20Skin%20Temperature%20from%20the%20Moderate%20Resolution%20Imaging%20Spectroradiometer%20(MODIS)%20on%20the%20NASA%20Terra%20satellite%20(GDS2)/granules/20000227000005-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0',
#   'Type': 'GET DATA',
#   'Subtype': 'OPENDAP DATA',
#   'Description': 'OPeNDAP request URL'}]

# %% [markdown]
# To access POCLOUD Earthdata Cloud data, you want URLs with 'Type': `'GET DATA'` and host `https://archive.podaac.earthdata.nasa.gov`.
#
# **Lesson note:** This URL points you to data that is archived in a cloud environment, namely, PO.DAAC's 'space' in the AWS S3 storage environment.

# %%
modis_url = modis_gran['items'][0]['umm']['RelatedUrls'][1]['URL']
modis_url
# Out:
# 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20000227000005-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc'

# %% [markdown]
# ### Download a file and open to explore

# %% [markdown]
# Download the file and open it with xarray in memory. This will pull cloud-stored data onto local space. *Note there is no charge for the user in doing so.*
#
# **Lesson note:** You are now downloading a file to your local space, from the PO.DAAC (Earthdata) archive that lives in the AWS cloud. Again, there is no charge for the user in doing so.

# %%
output_filename = 'tutorial1_data_MODIS.nc'
with request.urlopen(modis_url) as response, open(output_filename, 'wb') as out_file:
    print('Content Size:', response.headers['Content-length'])
    shutil.copyfileobj(response, out_file)
    print("Downloaded request to {}".format(output_filename))
# Out:
# Content Size: 27377431
# Downloaded request to tutorial1_data_MODIS.nc

# %% [markdown]
# You can preview metadata of the downloaded file with `ncdump`, or open in memory wtih `xarray`.

# %%
#!ncdump -h -s tutorial2_data_MODIS.nc

# %%
ds_MODIS = xr.open_dataset('tutorial1_data_MODIS.nc')
ds_MODIS
# Out:
# <xarray.Dataset>
# Dimensions:                      (ni: 1354, nj: 2030, time: 1)
# Coordinates:
#     lat                          (nj, ni) float32 ...
#     lon                          (nj, ni) float32 ...
#   * time                         (time) datetime64[ns] 2000-02-27
# Dimensions without coordinates: ni, nj
# Data variables:
#     sea_surface_temperature      (time, nj, ni) float32 ...
#     sst_dtime                    (time, nj, ni) timedelta64[ns] ...
#     quality_level                (time, nj, ni) float32 ...
#     sses_bias                    (time, nj, ni) float32 ...
#     sses_standard_deviation      (time, nj, ni) float32 ...
#     l2p_flags                    (time, nj, ni) int16 ...
#     sea_surface_temperature_4um  (time, nj, ni) float32 ...
#     quality_level_4um            (time, nj, ni) float32 ...
#     sses_bias_4um                (time, nj, ni) float32 ...
#     sses_standard_deviation_4um  (time, nj, ni) float32 ...
#     wind_speed                   (time, nj, ni) float32 ...
#     dt_analysis                  (time, nj, ni) float32 ...
# Attributes:
#     Conventions:                CF-1.7, ACDD-1.3
#     title:                      MODIS Terra L2P SST
#     summary:                    Sea surface temperature retrievals produced a...
#     references:                 GHRSST Data Processing Specification v2r5
#     institution:                NASA/JPL/OBPG/RSMAS
#     history:                    MODIS L2P created at JPL PO.DAAC
#     comment:                    L2P Core without DT analysis or other ancilla...
#     license:                    GHRSST and PO.DAAC protocol allow data use as...
#     id:                         MODIS_T-JPL-L2P-v2019.0
#     naming_authority:           org.ghrsst
#     product_version:            2019.0
#     uuid:                       f6e1f61d-c4a4-4c17-8354-0c15e12d688b
#     gds_version_id:             2.0
#     netcdf_version_id:          4.1
#     date_created:               20201010T211012Z
#     file_quality_level:         3
#     spatial_resolution:         1km
#     start_time:                 20000227T000000Z
#     time_coverage_start:        20000227T000000Z
#     stop_time:                  20000227T000459Z
#     time_coverage_end:          20000227T000459Z
#     northernmost_latitude:      -25.9045
#     southernmost_latitude:      -47.2401
#     easternmost_longitude:      4.14979
#     westernmost_longitude:      -27.5972
#     source:                     MODIS sea surface temperature observations fo...
#     platform:                   Terra
#     sensor:                     MODIS
#     metadata_link:              http://podaac.jpl.nasa.gov/ws/metadata/datase...
#     keywords:                   Oceans > Ocean Temperature > Sea Surface Temp...
#     keywords_vocabulary:        NASA Global Change Master Directory (GCMD) Sc...
#     standard_name_vocabulary:   NetCDF Climate and Forecast (CF) Metadata Con...
#     geospatial_lat_units:       degrees_north
#     geospatial_lat_resolution:  0.01
#     geospatial_lon_units:       degrees_east
#     geospatial_lon_resolution:  0.01
#     acknowledgment:             The MODIS L2P sea surface temperature data ar...
#     creator_name:               Ed Armstrong, JPL PO.DAAC
#     creator_email:              edward.m.armstrong@jpl.nasa.gov
#     creator_url:                http://podaac.jpl.nasa.gov
#     project:                    Group for High Resolution Sea Surface Tempera...
#     publisher_name:             The GHRSST Project Office
#     publisher_url:              http://www.ghrsst.org
#     publisher_email:            ghrsst-po@nceo.ac.uk
#     processing_level:           L2P
#     cdm_data_type:              swath
#     startDirection:             Ascending
#     endDirection:               Ascending
#     day_night_flag:             Night

# %% [markdown]
# Let's do a **quick plot** of the `sea_surface_temperature` variable:

# %%
ds_MODIS.sea_surface_temperature.plot()

# %% [markdown]
# We can see the time this file represents, and the variable, but it's hard to tell where on the map we are. Let's try it another way:

# %%
ax = plt.axes(projection=ccrs.PlateCarree())
ax.coastlines(zorder=3)

plt.scatter(ds_MODIS.lon, ds_MODIS.lat, lw=2, c=ds_MODIS.sea_surface_temperature)
plt.colorbar()
#plt.clim(-0.3, 0.3)

plt.show()

# %% [markdown]
# We can double check the data by plotting it in a separate application, such as Panoply. The data matches, in this case we're looking at MODIS SST somewhere in the Southern mid-Atlantic Ocean, at the first time stamp in the collection.
#
# <img align="left"
#      src="MODIS_SST_1stFile.png">

# %% [markdown]
# ## 3. Select data with shp file using the CMR API

# %% [markdown]
# Now that we've previewed the data and decided we'd like to request more, specific to our use case, we can pass the collection ID into the CMR API to *search* by geographic shape file. The service to *subset by shp* is also in development and should be available in 2021.

# %% [markdown]
# ### Access data selected by geographic shapefile
# We will request data overlapping the Gulf of Mexico by uploading a shape file with that boundary. This shape file can be one that you created, shred by a collaborator, or any other user, as long as it follows shape file convention. In essence, this following service allows the user to bring their own shape file to do a data search. The returned response will provide a list of data files from the cloud-based PO.DAAC archive (Earthdata Cloud) that intersect this given shape file.
#
# This requires the use of a multipart/form-data POST request. Supported shapefile formats include ESRI, GeoJSON, and KML. The associated mime-types are as follows:
#
# | Shapefile Format | mime-type |
# |:-----------------|----------:|
# | ESRI | application/shapefile+zip |
# | GeoJSON | application/geo+json |
# | KML | application/vnd.google-earth.kml+xml |
#
# ESRI shapefiles must be uploaded as a single .zip file.

# %% [markdown]
# ### Example with ESRI .shp file:
#
# We will now search with an ESRI shapefile and a temporal bound to limit our space and time region of interest. Namely, we will search over the Gulf of Mexico during the period 1 Aug 2020 to 1 Nov 2020, since we are interested in exploring how SST responds during the latest Atlantic hurricane season. Our spatial boundary shape file to search with over the Gulf of Mexico looks like this (previewed in QGIS):
#
# <img align="center"
#      src="Gulf_Mexico_shp_QGIS_zoom.png">
#
# **Lesson Note:** You are once again searching on data that lives in the PO.DAAC (Earthdata) cloud archive, from your local computer, by running this next code snippet. You are searching spatially (via shape file boundaries) and temporally.
#
# (Side note: the token parameter below allows you to access this new PO.DAAC cloud operational archive space. This is possible because your Earthdata login was added to a list of early access users to this cloud environment, for this workshop.)

# %%
# the URL of the CMR searvice
url = 'https://cmr.earthdata.nasa.gov/search/granules.umm_json'

#The shapefile we want to use in our search
shp_file = open('resources/gulf_shapefile.zip', 'rb')

#need to declare the file and the type we are uploading
files = {'shapefile':('gulf_shapefile.zip',shp_file, 'application/shapefile+zip')}

#used to define parameters such as the concept-id and things like temporal searches
parameters = {'collection_concept_id':'C1940475563-POCLOUD', 'token': _token, 'temporal':'2020-08-23T00:00:00Z,2020-08-29T00:00:00Z', 'page_size':33}

response = requests.post(url, files=files, params=parameters)
pp = pprint.PrettyPrinter(indent=2)
pp.pprint(response.json())
# Out:
# { 'hits': 39,
#   'items': [ { 'meta': { 'concept-id': 'G1968342093-POCLOUD',
#                          'concept-type': 'granule',
#                          'format': 'application/vnd.nasa.cmr.umm+json',
#                          'native-id': '20200823030000-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0',
#                          'provider-id': 'POCLOUD',
#                          'revision-date': '2020-11-18T09:05:46.289Z',
#                          'revision-id': 1},
#                'umm': { 'CollectionReference': { 'ShortName': 'MODIS_T-JPL-L2P-v2019.0',
#                                                  'Version': '2019.0'},
#                         'DataGranule': { 'ArchiveAndDistributionInformation': [ { 'Checksum': { 'Algorithm': 'MD5',
#                                                                                                 'Value': '15873ad45c46715e0f92a62af9174b56'},
#                                                                                   'Name': '20200823030000-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc.md5',
#                                                                                   'Size': 9.34600830078125e-05,
#                                                                                   'SizeInBytes': 98,
#                                                                                   'SizeUnit': 'MB'},
#                                                                                 { 'Checksum': { 'Algorithm': 'MD5',
#                                                                                                 'Value': '41d70fdbb65a8aea69f094224753b35c'},
#                                                                                   'Name': '20200823030000-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#                                                                                   'Size': 25.41091823577881,
#                                                                                   'SizeInBytes': 26645279,
#                                                                                   'SizeUnit': 'MB'}],
#                                          'DayNightFlag': 'Unspecified',
#                                          'ProductionDateTime': '2020-11-15T21:20:53.000Z'},
#                         'GranuleUR': '20200823030000-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0',
#                         'MetadataSpecification': { 'Name': 'UMM-G',
#                                                    'URL': 'https://cdn.earthdata.nasa.gov/umm/granule/v1.6.1',
#                                                    'Version': '1.6.1'},
#                         'ProviderDates': [ { 'Date': '2020-11-18T09:05:18.608Z',
#                                              'Type': 'Insert'},
#                                            { 'Date': '2020-11-18T09:05:18.608Z',
#                                              'Type': 'Update'}],
#                         'RelatedUrls': [ { 'Description': 'Download '
#                                                           '20200823030000-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc.md5',
#                                            'Type': 'EXTENDED METADATA',
#                                            'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MODIS_T-JPL-L2P-v2019.0/20200823030000-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc.md5'},
#                                          { 'Description': 'Download '
#                                                           '20200823030000-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#                                            'Type': 'GET DATA',
#                                            'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200823030000-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc'},
#                                          { 'Description': 'Download '
#                                                           '20200823030000-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.cmr.json',
#                                            'Type': 'EXTENDED METADATA',
#                                            'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MODIS_T-JPL-L2P-v2019.0/20200823030000-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.cmr.json'},
#                                          { 'Description': 'api endpoint to '
#                                                           'retrieve temporary '
#                                                           'credentials valid '
#                                                           'for same-region '
#                                                           'direct s3 access',
#                                            'Type': 'VIEW RELATED INFORMATION',
#                                            'URL': 'https://archive.podaac.earthdata.nasa.gov/s3credentials'},
#                                          { 'Description': 'OPeNDAP request URL',
#                                            'Subtype': 'OPENDAP DATA',
#                                            'Type': 'GET DATA',
#                                            'URL': 'https://opendap.earthdata.nasa.gov/providers/POCLOUD/collections/GHRSST%20Level%202P%20Global%20Sea%20Surface%20Skin%20Temperature%20from%20the%20Moderate%20Resolution%20Imaging%20Spectroradiometer%20(MODIS)%20on%20the%20NASA%20Terra%20satellite%20(GDS2)/granules/20200823030000-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0'}],
#                         'SpatialExtent': { 'HorizontalSpatialDomain': { 'Geometry': { 'BoundingRectangles': [ { 'EastBoundingCoordinate': -58.194,
#                                                                                                                 'NorthBoundingCoordinate': 28.534,
#                                                                                                                 'SouthBoundingCoordinate': 7.548,
#                                                                                                                 'WestBoundingCoordinate': -84.281}]}}},
#                         'TemporalExtent': { 'RangeDateTime': { 'BeginningDateTime': '2020-08-23T03:00:00.000Z',
#                                                                'EndingDateTime': '2020-08-23T03:04:59.000Z'}}}},
#              { 'meta': { 'concept-id': 'G1973524622-POCLOUD',
#                          'concept-type': 'granule',
#                          'format': 'application/vnd.nasa.cmr.umm+json',
#                          'native-id': '20200823030500-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0',
#                          'provider-id': 'POCLOUD',
#                          'revision-date': '2020-12-03T20:46:39.306Z',
#                          'revision-id': 1},
#                'umm': { 'CollectionReference': { 'ShortName': 'MODIS_T-JPL-L2P-v2019.0',
#                                                  'Version': '2019.0'},
#                         'DataGranule': { 'ArchiveAndDistributionInformation': [ { 'Checksum': { 'Algorithm': 'MD5',
#                                                                                                 'Value': '58ed1d6f9799705383908a4310a9875e'},
#                                                                                   'Name': '20200823030500-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc.md5',
#                                                                                   'Size': 9.34600830078125e-05,
#                                                                                   'SizeInBytes': 98,
#                                                                                   'SizeUnit': 'MB'},
#                                                                                 { 'Checksum': { 'Algorithm': 'MD5',
#                                                                                                 'Value': '12a40e05a4d55e45835d0d638f50052e'},
#                                                                                   'Name': '20200823030500-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#                                                                                   'Size': 22.298983573913574,
#                                                                                   'SizeInBytes': 23382179,
#                                                                                   'SizeUnit': 'MB'}],
#                                          'DayNightFlag': 'Unspecified',
#                                          'ProductionDateTime': '2020-11-15T21:20:33.000Z'},
#                         'GranuleUR': '20200823030500-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0',
#                         'MetadataSpecification': { 'Name': 'UMM-G',
#                                                    'URL': 'https://cdn.earthdata.nasa.gov/umm/granule/v1.6.1',
#                                                    'Version': '1.6.1'},
#                         'ProviderDates': [ { 'Date': '2020-12-03T20:46:15.339Z',
#                                              'Type': 'Insert'},
#                                            { 'Date': '2020-12-03T20:46:15.339Z',
#                                              'Type': 'Update'}],
#                         'RelatedUrls': [ { 'Description': 'Download '
#                                                           '20200823030500-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#                                            'Type': 'GET DATA',
#                                            'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200823030500-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc'},
#                                          { 'Description': 'Download '
#                                                           '20200823030500-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc.md5',
#                                            'Type': 'EXTENDED METADATA',
#                                            'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MODIS_T-JPL-L2P-v2019.0/20200823030500-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc.md5'},
#                                          { 'Description': 'Download '
#                                                           '20200823030500-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.cmr.json',
#                                            'Type': 'EXTENDED METADATA',
#                                            'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MODIS_T-JPL-L2P-v2019.0/20200823030500-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.cmr.json'},
#                                          { 'Description': 'api endpoint to '
#                                                           'retrieve temporary '
#                                                           'credentials valid '
#                                                           'for same-region '
#                                                           'direct s3 access',
#                                            'Type': 'VIEW RELATED INFORMATION',
#                                            'URL': 'https://archive.podaac.earthdata.nasa.gov/s3credentials'},
#                                          { 'Description': 'OPeNDAP request URL',
#                                            'Subtype': 'OPENDAP DATA',
#                                            'Type': 'GET DATA',
#                                            'URL': 'https://opendap.earthdata.nasa.gov/providers/POCLOUD/collections/GHRSST%20Level%202P%20Global%20Sea%20Surface%20Skin%20Temperature%20from%20the%20Moderate%20Resolution%20Imaging%20Spectroradiometer%20(MODIS)%20on%20the%20NASA%20Terra%20satellite%20(GDS2)/granules/20200823030500-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0'}],
#                         'SpatialExtent': { 'HorizontalSpatialDomain': { 'Geometry': { 'BoundingRectangles': [ { 'EastBoundingCoordinate': -61.109,
#                                                                                                                 'NorthBoundingCoordinate': 46.553,
#                                                                                                                 'SouthBoundingCoordinate': 25.163,
#                                                                                                                 'WestBoundingCoordinate': -92.199}]}}},
#                         'TemporalExtent': { 'RangeDateTime': { 'BeginningDateTime': '2020-08-23T03:05:00.000Z',
#                                                                'EndingDateTime': '2020-08-23T03:10:00.000Z'}}}},
#              { 'meta': { 'concept-id': 'G1968318336-POCLOUD',
#                          'concept-type': 'granule',
#                          'format': 'application/vnd.nasa.cmr.umm+json',
#                          'native-id': '20200823044000-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0',
#                          'provider-id': 'POCLOUD',
#                          'revision-date': '2020-11-18T07:39:42.147Z',
#                          'revision-id': 1},
#                'umm': { 'CollectionReference': { 'ShortName': 'MODIS_T-JPL-L2P-v2019.0',
#                                                  'Version': '2019.0'},
#                         'DataGranule': { 'ArchiveAndDistributionInformation': [ { 'Checksum': { 'Algorithm': 'MD5',
#                                                                                                 'Value': '4aed6bed25753b9a27c48c1b8d7e5617'},
#                                                                                   'Name': '20200823044000-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#                                                                                   'Size': 21.475051879882812,
#                                                                                   'SizeInBytes': 22518224,
#                                                                                   'SizeUnit': 'MB'},
#                                                                                 { 'Checksum': { 'Algorithm': 'MD5',
#                                                                                                 'Value': 'cd2f4b82995145c7bd640ff3c6087772'},
#                                                                                   'Name': '20200823044000-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc.md5',
#                                                                                   'Size': 9.34600830078125e-05,
#                                                                                   'SizeInBytes': 98,
#                                                                                   'SizeUnit': 'MB'}],
#                                          'DayNightFlag': 'Unspecified',
#                                          'ProductionDateTime': '2020-11-15T21:30:30.000Z'},
#                         'GranuleUR': '20200823044000-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0',
#                         'MetadataSpecification': { 'Name': 'UMM-G',
#                                                    'URL': 'https://cdn.earthdata.nasa.gov/umm/granule/v1.6.1',
#                                                    'Version': '1.6.1'},
#                         'ProviderDates': [ { 'Date': '2020-11-18T07:39:17.202Z',
#                                              'Type': 'Insert'},
#                                            { 'Date': '2020-11-18T07:39:17.203Z',
#                                              'Type': 'Update'}],
#                         'RelatedUrls': [ { 'Description': 'Download '
#                                                           '20200823044000-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#                                            'Type': 'GET DATA',
#                                            'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200823044000-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc'},
#                                          { 'Description': 'Download '
#                                                           '20200823044000-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc.md5',
#                                            'Type': 'EXTENDED METADATA',
#                                            'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MODIS_T-JPL-L2P-v2019.0/20200823044000-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc.md5'},
#                                          { 'Description': 'Download '
#                                                           '20200823044000-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.cmr.json',
#                                            'Type': 'EXTENDED METADATA',
#                                            'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MODIS_T-JPL-L2P-v2019.0/20200823044000-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.cmr.json'},
#                                          { 'Description': 'api endpoint to '
#                                                           'retrieve temporary '
#                                                           'credentials valid '
#                                                           'for same-region '
#                                                           'direct s3 access',
#                                            'Type': 'VIEW RELATED INFORMATION',
#                                            'URL': 'https://archive.podaac.earthdata.nasa.gov/s3credentials'},
#                                          { 'Description': 'OPeNDAP request URL',
#                                            'Subtype': 'OPENDAP DATA',
#                                            'Type': 'GET DATA',
#                                            'URL': 'https://opendap.earthdata.nasa.gov/providers/POCLOUD/collections/GHRSST%20Level%202P%20Global%20Sea%20Surface%20Skin%20Temperature%20from%20the%20Moderate%20Resolution%20Imaging%20Spectroradiometer%20(MODIS)%20on%20the%20NASA%20Terra%20satellite%20(GDS2)/granules/20200823044000-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0'}],
#                         'SpatialExtent': { 'HorizontalSpatialDomain': { 'Geometry': { 'BoundingRectangles': [ { 'EastBoundingCoordinate': -83.637,
#                                                                                                                 'NorthBoundingCoordinate': 32.547,
#                                                                                                                 'SouthBoundingCoordinate': 11.515,
#                                                                                                                 'WestBoundingCoordinate': -110.446}]}}},
#                         'TemporalExtent': { 'RangeDateTime': { 'BeginningDateTime': '2020-08-23T04:40:00.000Z',
#                                                                'EndingDateTime': '2020-08-23T04:44:59.000Z'}}}},
#              { 'meta': { 'concept-id': 'G1968138578-POCLOUD',
#                          'concept-type': 'granule',
#                          'format': 'application/vnd.nasa.cmr.umm+json',
#                          'native-id': '20200823044500-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0',
#                          'provider-id': 'POCLOUD',
#                          'revision-date': '2020-11-17T20:50:46.703Z',
#                          'revision-id': 1},
#                'umm': { 'CollectionReference': { 'ShortName': 'MODIS_T-JPL-L2P-v2019.0',
#                                                  'Version': '2019.0'},
#                         'DataGranule': { 'ArchiveAndDistributionInformation': [ { 'Checksum': { 'Algorithm': 'MD5',
#                                                                                                 'Value': 'ac8816b639bd2701d5e8af45135136cc'},
#                                                                                   'Name': '20200823044500-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#                                                                                   'Size': 16.384026527404785,
#                                                                                   'SizeInBytes': 17179897,
#                                                                                   'SizeUnit': 'MB'},
#                                                                                 { 'Checksum': { 'Algorithm': 'MD5',
#                                                                                                 'Value': '653064adf713708eda6a4013185593c8'},
#                                                                                   'Name': '20200823044500-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc.md5',
#                                                                                   'Size': 9.34600830078125e-05,
#                                                                                   'SizeInBytes': 98,
#                                                                                   'SizeUnit': 'MB'}],
#                                          'DayNightFlag': 'Unspecified',
#                                          'ProductionDateTime': '2020-11-15T21:30:30.000Z'},
#                         'GranuleUR': '20200823044500-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0',
#                         'MetadataSpecification': { 'Name': 'UMM-G',
#                                                    'URL': 'https://cdn.earthdata.nasa.gov/umm/granule/v1.6.1',
#                                                    'Version': '1.6.1'},
#                         'ProviderDates': [ { 'Date': '2020-11-17T20:50:23.728Z',
#                                              'Type': 'Insert'},
#                                            { 'Date': '2020-11-17T20:50:23.728Z',
#                                              'Type': 'Update'}],
#                         'RelatedUrls': [ { 'Description': 'Download '
#                                                           '20200823044500-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc.md5',
#                                            'Type': 'EXTENDED METADATA',
#                                            'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MODIS_T-JPL-L2P-v2019.0/20200823044500-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc.md5'},
#                                          { 'Description': 'Download '
#                                                           '20200823044500-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#                                            'Type': 'GET DATA',
#                                            'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200823044500-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc'},
#                                          { 'Description': 'Download '
#                                                           '20200823044500-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.cmr.json',
#                                            'Type': 'EXTENDED METADATA',
#                                            'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MODIS_T-JPL-L2P-v2019.0/20200823044500-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.cmr.json'},
#                                          { 'Description': 'api endpoint to '
#                                                           'retrieve temporary '
#                                                           'credentials valid '
#                                                           'for same-region '
#                                                           'direct s3 access',
#                                            'Type': 'VIEW RELATED INFORMATION',
#                                            'URL': 'https://archive.podaac.earthdata.nasa.gov/s3credentials'},
#                                          { 'Description': 'OPeNDAP request URL',
#                                            'Subtype': 'OPENDAP DATA',
#                                            'Type': 'GET DATA',
#                                            'URL': 'https://opendap.earthdata.nasa.gov/providers/POCLOUD/collections/GHRSST%20Level%202P%20Global%20Sea%20Surface%20Skin%20Temperature%20from%20the%20Moderate%20Resolution%20Imaging%20Spectroradiometer%20(MODIS)%20on%20the%20NASA%20Terra%20satellite%20(GDS2)/granules/20200823044500-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0'}],
#                         'SpatialExtent': { 'HorizontalSpatialDomain': { 'Geometry': { 'BoundingRectangles': [ { 'EastBoundingCoordinate': -86.372,
#                                                                                                                 'NorthBoundingCoordinate': 50.47,
#                                                                                                                 'SouthBoundingCoordinate': 29.049,
#                                                                                                                 'WestBoundingCoordinate': -119.293}]}}},
#                         'TemporalExtent': { 'RangeDateTime': { 'BeginningDateTime': '2020-08-23T04:45:00.000Z',
#                                                                'EndingDateTime': '2020-08-23T04:49:59.000Z'}}}},
#              { 'meta': { 'concept-id': 'G1968168155-POCLOUD',
#                          'concept-type': 'granule',
#                          'format': 'application/vnd.nasa.cmr.umm+json',
#                          'native-id': '20200823164501-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0',
#                          'provider-id': 'POCLOUD',
#                          'revision-date': '2020-11-17T22:47:53.034Z',
#                          'revision-id': 1},
#                'umm': { 'CollectionReference': { 'ShortName': 'MODIS_T-JPL-L2P-v2019.0',
#                                                  'Version': '2019.0'},
#                         'DataGranule': { 'ArchiveAndDistributionInformation': [ { 'Checksum': { 'Algorithm': 'MD5',
#                                                                                                 'Value': '6dcddf6707a96f21083385aad68fd836'},
#                                                                                   'Name': '20200823164501-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc.md5',
#                                                                                   'Size': 9.34600830078125e-05,
#                                                                                   'SizeInBytes': 98,
#                                                                                   'SizeUnit': 'MB'},
#                                                                                 { 'Checksum': { 'Algorithm': 'MD5',
#                                                                                                 'Value': '79d939cd2d41dcc2c8a07f435b8de0c1'},
#                                                                                   'Name': '20200823164501-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#                                                                                   'Size': 17.6124906539917,
#                                                                                   'SizeInBytes': 18468035,
#                                                                                   'SizeUnit': 'MB'}],
#                                          'DayNightFlag': 'Unspecified',
#                                          'ProductionDateTime': '2020-11-15T22:40:35.000Z'},
#                         'GranuleUR': '20200823164501-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0',
#                         'MetadataSpecification': { 'Name': 'UMM-G',
#                                                    'URL': 'https://cdn.earthdata.nasa.gov/umm/granule/v1.6.1',
#                                                    'Version': '1.6.1'},
#                         'ProviderDates': [ { 'Date': '2020-11-17T22:47:28.595Z',
#                                              'Type': 'Insert'},
#                                            { 'Date': '2020-11-17T22:47:28.595Z',
#                                              'Type': 'Update'}],
#                         'RelatedUrls': [ { 'Description': 'Download '
#                                                           '20200823164501-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#                                            'Type': 'GET DATA',
#                                            'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200823164501-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc'},
#                                          { 'Description': 'Download '
#                                                           '20200823164501-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc.md5',
#                                            'Type': 'EXTENDED METADATA',
#                                            'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MODIS_T-JPL-L2P-v2019.0/20200823164501-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc.md5'},
#                                          { 'Description': 'Download '
#                                                           '20200823164501-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.cmr.json',
#                                            'Type': 'EXTENDED METADATA',
#                                            'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MODIS_T-JPL-L2P-v2019.0/20200823164501-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.cmr.json'},
#                                          { 'Description': 'api endpoint to '
#                                                           'retrieve temporary '
#                                                           'credentials valid '
#                                                           'for same-region '
#                                                           'direct s3 access',
#                                            'Type': 'VIEW RELATED INFORMATION',
#                                            'URL': 'https://archive.podaac.earthdata.nasa.gov/s3credentials'},
#                                          { 'Description': 'OPeNDAP request URL',
#                                            'Subtype': 'OPENDAP DATA',
#                                            'Type': 'GET DATA',
#                                            'URL': 'https://opendap.earthdata.nasa.gov/providers/POCLOUD/collections/GHRSST%20Level%202P%20Global%20Sea%20Surface%20Skin%20Temperature%20from%20the%20Moderate%20Resolution%20Imaging%20Spectroradiometer%20(MODIS)%20on%20the%20NASA%20Terra%20satellite%20(GDS2)/granules/20200823164501-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0'}],
#                         'SpatialExtent': { 'HorizontalSpatialDomain': { 'Geometry': { 'BoundingRectangles': [ { 'EastBoundingCoordinate': -70.774,
#                                                                                                                 'NorthBoundingCoordinate': 47.777,
#                                                                                                                 'SouthBoundingCoordinate': 26.375,
#                                                                                                                 'WestBoundingCoordinate': -102.342}]}}},
#                         'TemporalExtent': { 'RangeDateTime': { 'BeginningDateTime': '2020-08-23T16:45:01.000Z',
#                                                                'EndingDateTime': '2020-08-23T16:49:59.000Z'}}}},
#              { 'meta': { 'concept-id': 'G1968320405-POCLOUD',
#                          'concept-type': 'granule',
#                          'format': 'application/vnd.nasa.cmr.umm+json',
#                          'native-id': '20200823165001-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0',
#                          'provider-id': 'POCLOUD',
#                          'revision-date': '2020-11-18T07:45:53.201Z',
#                          'revision-id': 1},
#                'umm': { 'CollectionReference': { 'ShortName': 'MODIS_T-JPL-L2P-v2019.0',
#                                                  'Version': '2019.0'},
#                         'DataGranule': { 'ArchiveAndDistributionInformation': [ { 'Checksum': { 'Algorithm': 'MD5',
#                                                                                                 'Value': 'e8f99e229d38120596edc15f1e89ee50'},
#                                                                                   'Name': '20200823165001-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#                                                                                   'Size': 22.107858657836914,
#                                                                                   'SizeInBytes': 23181770,
#                                                                                   'SizeUnit': 'MB'},
#                                                                                 { 'Checksum': { 'Algorithm': 'MD5',
#                                                                                                 'Value': '752040678420aeb07d1626d5f266acc2'},
#                                                                                   'Name': '20200823165001-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc.md5',
#                                                                                   'Size': 9.34600830078125e-05,
#                                                                                   'SizeInBytes': 98,
#                                                                                   'SizeUnit': 'MB'}],
#                                          'DayNightFlag': 'Unspecified',
#                                          'ProductionDateTime': '2020-11-15T22:40:34.000Z'},
#                         'GranuleUR': '20200823165001-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0',
#                         'MetadataSpecification': { 'Name': 'UMM-G',
#                                                    'URL': 'https://cdn.earthdata.nasa.gov/umm/granule/v1.6.1',
#                                                    'Version': '1.6.1'},
#                         'ProviderDates': [ { 'Date': '2020-11-18T07:45:28.440Z',
#                                              'Type': 'Insert'},
#                                            { 'Date': '2020-11-18T07:45:28.441Z',
#                                              'Type': 'Update'}],
#                         'RelatedUrls': [ { 'Description': 'Download '
#                                                           '20200823165001-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#                                            'Type': 'GET DATA',
#                                            'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200823165001-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc'},
#                                          { 'Description': 'Download '
#                                                           '20200823165001-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc.md5',
#                                            'Type': 'EXTENDED METADATA',
#                                            'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MODIS_T-JPL-L2P-v2019.0/20200823165001-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc.md5'},
#                                          { 'Description': 'Download '
#                                                           '20200823165001-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.cmr.json',
#                                            'Type': 'EXTENDED METADATA',
#                                            'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MODIS_T-JPL-L2P-v2019.0/20200823165001-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.cmr.json'},
#                                          { 'Description': 'api endpoint to '
#                                                           'retrieve temporary '
#                                                           'credentials valid '
#                                                           'for same-region '
#                                                           'direct s3 access',
#                                            'Type': 'VIEW RELATED INFORMATION',
#                                            'URL': 'https://archive.podaac.earthdata.nasa.gov/s3credentials'},
#                                          { 'Description': 'OPeNDAP request URL',
#                                            'Subtype': 'OPENDAP DATA',
#                                            'Type': 'GET DATA',
#                                            'URL': 'https://opendap.earthdata.nasa.gov/providers/POCLOUD/collections/GHRSST%20Level%202P%20Global%20Sea%20Surface%20Skin%20Temperature%20from%20the%20Moderate%20Resolution%20Imaging%20Spectroradiometer%20(MODIS)%20on%20the%20NASA%20Terra%20satellite%20(GDS2)/granules/20200823165001-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0'}],
#                         'SpatialExtent': { 'HorizontalSpatialDomain': { 'Geometry': { 'BoundingRectangles': [ { 'EastBoundingCoordinate': -78.928,
#                                                                                                                 'NorthBoundingCoordinate': 29.848,
#                                                                                                                 'SouthBoundingCoordinate': 8.782,
#                                                                                                                 'WestBoundingCoordinate': -105.196}]}}},
#                         'TemporalExtent': { 'RangeDateTime': { 'BeginningDateTime': '2020-08-23T16:50:01.000Z',
#                                                                'EndingDateTime': '2020-08-23T16:54:59.000Z'}}}},
#              { 'meta': { 'concept-id': 'G1968195366-POCLOUD',
#                          'concept-type': 'granule',
#                          'format': 'application/vnd.nasa.cmr.umm+json',
#                          'native-id': '20200823182501-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0',
#                          'provider-id': 'POCLOUD',
#                          'revision-date': '2020-11-18T00:39:46.452Z',
#                          'revision-id': 1},
#                'umm': { 'CollectionReference': { 'ShortName': 'MODIS_T-JPL-L2P-v2019.0',
#                                                  'Version': '2019.0'},
#                         'DataGranule': { 'ArchiveAndDistributionInformation': [ { 'Checksum': { 'Algorithm': 'MD5',
#                                                                                                 'Value': '8839e0ef8bcff900995369064e7c90ac'},
#                                                                                   'Name': '20200823182501-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc.md5',
#                                                                                   'Size': 9.34600830078125e-05,
#                                                                                   'SizeInBytes': 98,
#                                                                                   'SizeUnit': 'MB'},
#                                                                                 { 'Checksum': { 'Algorithm': 'MD5',
#                                                                                                 'Value': 'd0413f1ba49f4f0c6f3bc44e398252a0'},
#                                                                                   'Name': '20200823182501-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#                                                                                   'Size': 18.87834930419922,
#                                                                                   'SizeInBytes': 19795384,
#                                                                                   'SizeUnit': 'MB'}],
#                                          'DayNightFlag': 'Unspecified',
#                                          'ProductionDateTime': '2020-11-15T22:50:34.000Z'},
#                         'GranuleUR': '20200823182501-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0',
#                         'MetadataSpecification': { 'Name': 'UMM-G',
#                                                    'URL': 'https://cdn.earthdata.nasa.gov/umm/granule/v1.6.1',
#                                                    'Version': '1.6.1'},
#                         'ProviderDates': [ { 'Date': '2020-11-18T00:39:24.040Z',
#                                              'Type': 'Insert'},
#                                            { 'Date': '2020-11-18T00:39:24.041Z',
#                                              'Type': 'Update'}],
#                         'RelatedUrls': [ { 'Description': 'Download '
#                                                           '20200823182501-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc.md5',
#                                            'Type': 'EXTENDED METADATA',
#                                            'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MODIS_T-JPL-L2P-v2019.0/20200823182501-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc.md5'},
#                                          { 'Description': 'Download '
#                                                           '20200823182501-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#                                            'Type': 'GET DATA',
#                                            'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200823182501-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc'},
#                                          { 'Description': 'Download '
#                                                           '20200823182501-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.cmr.json',
#                                            'Type': 'EXTENDED METADATA',
#                                            'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MODIS_T-JPL-L2P-v2019.0/20200823182501-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.cmr.json'},
#                                          { 'Description': 'api endpoint to '
#                                                           'retrieve temporary '
#                                                           'credentials valid '
#                                                           'for same-region '
#                                                           'direct s3 access',
#                                            'Type': 'VIEW RELATED INFORMATION',
#                                            'URL': 'https://archive.podaac.earthdata.nasa.gov/s3credentials'},
#                                          { 'Description': 'OPeNDAP request URL',
#                                            'Subtype': 'OPENDAP DATA',
#                                            'Type': 'GET DATA',
#                                            'URL': 'https://opendap.earthdata.nasa.gov/providers/POCLOUD/collections/GHRSST%20Level%202P%20Global%20Sea%20Surface%20Skin%20Temperature%20from%20the%20Moderate%20Resolution%20Imaging%20Spectroradiometer%20(MODIS)%20on%20the%20NASA%20Terra%20satellite%20(GDS2)/granules/20200823182501-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0'}],
#                         'SpatialExtent': { 'HorizontalSpatialDomain': { 'Geometry': { 'BoundingRectangles': [ { 'EastBoundingCoordinate': -97.705,
#                                                                                                                 'NorthBoundingCoordinate': 43.775,
#                                                                                                                 'SouthBoundingCoordinate': 22.476,
#                                                                                                                 'WestBoundingCoordinate': -127.632}]}}},
#                         'TemporalExtent': { 'RangeDateTime': { 'BeginningDateTime': '2020-08-23T18:25:01.000Z',
#                                                                'EndingDateTime': '2020-08-23T18:29:59.000Z'}}}},
#              { 'meta': { 'concept-id': 'G1968355598-POCLOUD',
#                          'concept-type': 'granule',
#                          'format': 'application/vnd.nasa.cmr.umm+json',
#                          'native-id': '20200824034501-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0',
#                          'provider-id': 'POCLOUD',
#                          'revision-date': '2020-11-18T09:52:05.708Z',
#                          'revision-id': 1},
#                'umm': { 'CollectionReference': { 'ShortName': 'MODIS_T-JPL-L2P-v2019.0',
#                                                  'Version': '2019.0'},
#                         'DataGranule': { 'ArchiveAndDistributionInformation': [ { 'Checksum': { 'Algorithm': 'MD5',
#                                                                                                 'Value': '11f4437d8801396880646810710df943'},
#                                                                                   'Name': '20200824034501-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#                                                                                   'Size': 24.06425666809082,
#                                                                                   'SizeInBytes': 25233202,
#                                                                                   'SizeUnit': 'MB'},
#                                                                                 { 'Checksum': { 'Algorithm': 'MD5',
#                                                                                                 'Value': '3293de4e001fbf9801f87342584210be'},
#                                                                                   'Name': '20200824034501-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc.md5',
#                                                                                   'Size': 9.34600830078125e-05,
#                                                                                   'SizeInBytes': 98,
#                                                                                   'SizeUnit': 'MB'}],
#                                          'DayNightFlag': 'Unspecified',
#                                          'ProductionDateTime': '2020-11-15T19:20:33.000Z'},
#                         'GranuleUR': '20200824034501-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0',
#                         'MetadataSpecification': { 'Name': 'UMM-G',
#                                                    'URL': 'https://cdn.earthdata.nasa.gov/umm/granule/v1.6.1',
#                                                    'Version': '1.6.1'},
#                         'ProviderDates': [ { 'Date': '2020-11-18T09:51:39.628Z',
#                                              'Type': 'Insert'},
#                                            { 'Date': '2020-11-18T09:51:39.629Z',
#                                              'Type': 'Update'}],
#                         'RelatedUrls': [ { 'Description': 'Download '
#                                                           '20200824034501-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#                                            'Type': 'GET DATA',
#                                            'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200824034501-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc'},
#                                          { 'Description': 'Download '
#                                                           '20200824034501-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc.md5',
#                                            'Type': 'EXTENDED METADATA',
# ...
#                                            'Type': 'EXTENDED METADATA',
#                                            'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MODIS_T-JPL-L2P-v2019.0/20200827162501-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc.md5'},
#                                          { 'Description': 'Download '
#                                                           '20200827162501-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#                                            'Type': 'GET DATA',
#                                            'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200827162501-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc'},
#                                          { 'Description': 'Download '
#                                                           '20200827162501-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.cmr.json',
#                                            'Type': 'EXTENDED METADATA',
#                                            'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MODIS_T-JPL-L2P-v2019.0/20200827162501-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.cmr.json'},
#                                          { 'Description': 'api endpoint to '
#                                                           'retrieve temporary '
#                                                           'credentials valid '
#                                                           'for same-region '
#                                                           'direct s3 access',
#                                            'Type': 'VIEW RELATED INFORMATION',
#                                            'URL': 'https://archive.podaac.earthdata.nasa.gov/s3credentials'},
#                                          { 'Description': 'OPeNDAP request URL',
#                                            'Subtype': 'OPENDAP DATA',
#                                            'Type': 'GET DATA',
#                                            'URL': 'https://opendap.earthdata.nasa.gov/providers/POCLOUD/collections/GHRSST%20Level%202P%20Global%20Sea%20Surface%20Skin%20Temperature%20from%20the%20Moderate%20Resolution%20Imaging%20Spectroradiometer%20(MODIS)%20on%20the%20NASA%20Terra%20satellite%20(GDS2)/granules/20200827162501-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0'}],
#                         'SpatialExtent': { 'HorizontalSpatialDomain': { 'Geometry': { 'BoundingRectangles': [ { 'EastBoundingCoordinate': -72.394,
#                                                                                                                 'NorthBoundingCoordinate': 30.838,
#                                                                                                                 'SouthBoundingCoordinate': 9.76,
#                                                                                                                 'WestBoundingCoordinate': -98.837}]}}},
#                         'TemporalExtent': { 'RangeDateTime': { 'BeginningDateTime': '2020-08-27T16:25:01.000Z',
#                                                                'EndingDateTime': '2020-08-27T16:29:59.000Z'}}}},
#              { 'meta': { 'concept-id': 'G1968257078-POCLOUD',
#                          'concept-type': 'granule',
#                          'format': 'application/vnd.nasa.cmr.umm+json',
#                          'native-id': '20200827180001-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0',
#                          'provider-id': 'POCLOUD',
#                          'revision-date': '2020-11-18T03:46:56.928Z',
#                          'revision-id': 1},
#                'umm': { 'CollectionReference': { 'ShortName': 'MODIS_T-JPL-L2P-v2019.0',
#                                                  'Version': '2019.0'},
#                         'DataGranule': { 'ArchiveAndDistributionInformation': [ { 'Checksum': { 'Algorithm': 'MD5',
#                                                                                                 'Value': '61d41b1b6cbdc4b3568d5675e89ca001'},
#                                                                                   'Name': '20200827180001-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc.md5',
#                                                                                   'Size': 9.34600830078125e-05,
#                                                                                   'SizeInBytes': 98,
#                                                                                   'SizeUnit': 'MB'},
#                                                                                 { 'Checksum': { 'Algorithm': 'MD5',
#                                                                                                 'Value': '9a7e80fe0c162a200f07967e23acd775'},
#                                                                                   'Name': '20200827180001-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#                                                                                   'Size': 16.69976806640625,
#                                                                                   'SizeInBytes': 17510976,
#                                                                                   'SizeUnit': 'MB'}],
#                                          'DayNightFlag': 'Unspecified',
#                                          'ProductionDateTime': '2020-11-15T16:30:54.000Z'},
#                         'GranuleUR': '20200827180001-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0',
#                         'MetadataSpecification': { 'Name': 'UMM-G',
#                                                    'URL': 'https://cdn.earthdata.nasa.gov/umm/granule/v1.6.1',
#                                                    'Version': '1.6.1'},
#                         'ProviderDates': [ { 'Date': '2020-11-18T03:46:32.752Z',
#                                              'Type': 'Insert'},
#                                            { 'Date': '2020-11-18T03:46:32.753Z',
#                                              'Type': 'Update'}],
#                         'RelatedUrls': [ { 'Description': 'Download '
#                                                           '20200827180001-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc.md5',
#                                            'Type': 'EXTENDED METADATA',
#                                            'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MODIS_T-JPL-L2P-v2019.0/20200827180001-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc.md5'},
#                                          { 'Description': 'Download '
#                                                           '20200827180001-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#                                            'Type': 'GET DATA',
#                                            'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200827180001-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc'},
#                                          { 'Description': 'Download '
#                                                           '20200827180001-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.cmr.json',
#                                            'Type': 'EXTENDED METADATA',
#                                            'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MODIS_T-JPL-L2P-v2019.0/20200827180001-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.cmr.json'},
#                                          { 'Description': 'api endpoint to '
#                                                           'retrieve temporary '
#                                                           'credentials valid '
#                                                           'for same-region '
#                                                           'direct s3 access',
#                                            'Type': 'VIEW RELATED INFORMATION',
#                                            'URL': 'https://archive.podaac.earthdata.nasa.gov/s3credentials'},
#                                          { 'Description': 'OPeNDAP request URL',
#                                            'Subtype': 'OPENDAP DATA',
#                                            'Type': 'GET DATA',
#                                            'URL': 'https://opendap.earthdata.nasa.gov/providers/POCLOUD/collections/GHRSST%20Level%202P%20Global%20Sea%20Surface%20Skin%20Temperature%20from%20the%20Moderate%20Resolution%20Imaging%20Spectroradiometer%20(MODIS)%20on%20the%20NASA%20Terra%20satellite%20(GDS2)/granules/20200827180001-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0'}],
#                         'SpatialExtent': { 'HorizontalSpatialDomain': { 'Geometry': { 'BoundingRectangles': [ { 'EastBoundingCoordinate': -91.005,
#                                                                                                                 'NorthBoundingCoordinate': 44.765,
#                                                                                                                 'SouthBoundingCoordinate': 23.442,
#                                                                                                                 'WestBoundingCoordinate': -121.307}]}}},
#                         'TemporalExtent': { 'RangeDateTime': { 'BeginningDateTime': '2020-08-27T18:00:01.000Z',
#                                                                'EndingDateTime': '2020-08-27T18:04:59.000Z'}}}},
#              { 'meta': { 'concept-id': 'G1968266162-POCLOUD',
#                          'concept-type': 'granule',
#                          'format': 'application/vnd.nasa.cmr.umm+json',
#                          'native-id': '20200828032000-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0',
#                          'provider-id': 'POCLOUD',
#                          'revision-date': '2020-11-18T04:18:55.060Z',
#                          'revision-id': 1},
#                'umm': { 'CollectionReference': { 'ShortName': 'MODIS_T-JPL-L2P-v2019.0',
#                                                  'Version': '2019.0'},
#                         'DataGranule': { 'ArchiveAndDistributionInformation': [ { 'Checksum': { 'Algorithm': 'MD5',
#                                                                                                 'Value': 'a627c4b2ea0b23ea782af74874150ac1'},
#                                                                                   'Name': '20200828032000-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#                                                                                   'Size': 25.449161529541016,
#                                                                                   'SizeInBytes': 26685380,
#                                                                                   'SizeUnit': 'MB'},
#                                                                                 { 'Checksum': { 'Algorithm': 'MD5',
#                                                                                                 'Value': '74512d29fb0df7e050f24fbd219e44ca'},
#                                                                                   'Name': '20200828032000-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc.md5',
#                                                                                   'Size': 9.34600830078125e-05,
#                                                                                   'SizeInBytes': 98,
#                                                                                   'SizeUnit': 'MB'}],
#                                          'DayNightFlag': 'Unspecified',
#                                          'ProductionDateTime': '2020-11-15T04:40:50.000Z'},
#                         'GranuleUR': '20200828032000-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0',
#                         'MetadataSpecification': { 'Name': 'UMM-G',
#                                                    'URL': 'https://cdn.earthdata.nasa.gov/umm/granule/v1.6.1',
#                                                    'Version': '1.6.1'},
#                         'ProviderDates': [ { 'Date': '2020-11-18T04:18:30.845Z',
#                                              'Type': 'Insert'},
#                                            { 'Date': '2020-11-18T04:18:30.846Z',
#                                              'Type': 'Update'}],
#                         'RelatedUrls': [ { 'Description': 'Download '
#                                                           '20200828032000-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#                                            'Type': 'GET DATA',
#                                            'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200828032000-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc'},
#                                          { 'Description': 'Download '
#                                                           '20200828032000-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc.md5',
#                                            'Type': 'EXTENDED METADATA',
#                                            'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MODIS_T-JPL-L2P-v2019.0/20200828032000-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc.md5'},
#                                          { 'Description': 'Download '
#                                                           '20200828032000-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.cmr.json',
#                                            'Type': 'EXTENDED METADATA',
#                                            'URL': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-public/MODIS_T-JPL-L2P-v2019.0/20200828032000-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.cmr.json'},
#                                          { 'Description': 'api endpoint to '
#                                                           'retrieve temporary '
#                                                           'credentials valid '
#                                                           'for same-region '
#                                                           'direct s3 access',
#                                            'Type': 'VIEW RELATED INFORMATION',
#                                            'URL': 'https://archive.podaac.earthdata.nasa.gov/s3credentials'},
#                                          { 'Description': 'OPeNDAP request URL',
#                                            'Subtype': 'OPENDAP DATA',
#                                            'Type': 'GET DATA',
#                                            'URL': 'https://opendap.earthdata.nasa.gov/providers/POCLOUD/collections/GHRSST%20Level%202P%20Global%20Sea%20Surface%20Skin%20Temperature%20from%20the%20Moderate%20Resolution%20Imaging%20Spectroradiometer%20(MODIS)%20on%20the%20NASA%20Terra%20satellite%20(GDS2)/granules/20200828032000-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0'}],
#                         'SpatialExtent': { 'HorizontalSpatialDomain': { 'Geometry': { 'BoundingRectangles': [ { 'EastBoundingCoordinate': -63.763,
#                                                                                                                 'NorthBoundingCoordinate': 33.851,
#                                                                                                                 'SouthBoundingCoordinate': 12.714,
#                                                                                                                 'WestBoundingCoordinate': -90.866}]}}},
#                         'TemporalExtent': { 'RangeDateTime': { 'BeginningDateTime': '2020-08-28T03:20:00.000Z',
#                                                                'EndingDateTime': '2020-08-28T03:25:00.000Z'}}}}],
#   'took': 180}

# %% [markdown]
# ## 4. Preview the selected data

# %% [markdown]
# The `POCLOUD` in the response above signals that you are indeed searching on data from the PO.DAAC archive within the Earthdata Cloud.
#
# Let's take a look at the url for the first data file this spatial and temporal search result returned:

# %% [markdown]
# **For now, let's plot the first files** from our query, that we have downloaded to your local space.

# %%
new_modis_url = response.json()['items'][0]['umm']['RelatedUrls'][1]['URL']
new_modis_url
# Out:
# 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200823030000-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc'

# %%
output_filename = 'tutorial1_data_MODIS_from_shp.nc'
with request.urlopen(new_modis_url) as result, open(output_filename, 'wb') as out_file:
    print('Content Size:', result.headers['Content-length'])
    shutil.copyfileobj(result, out_file)
    print("Downloaded request to {}".format(output_filename))
# Out:
# Content Size: 26645279
# Downloaded request to tutorial1_data_MODIS_from_shp.nc

# %%
ds_MODIS_shp = xr.open_dataset('tutorial1_data_MODIS_from_shp.nc')
ds_MODIS_shp
# Out:
# <xarray.Dataset>
# Dimensions:                      (ni: 1354, nj: 2030, time: 1)
# Coordinates:
#     lat                          (nj, ni) float32 ...
#     lon                          (nj, ni) float32 ...
#   * time                         (time) datetime64[ns] 2020-08-23T03:00:00
# Dimensions without coordinates: ni, nj
# Data variables:
#     sea_surface_temperature      (time, nj, ni) float32 ...
#     sst_dtime                    (time, nj, ni) timedelta64[ns] ...
#     quality_level                (time, nj, ni) float32 ...
#     sses_bias                    (time, nj, ni) float32 ...
#     sses_standard_deviation      (time, nj, ni) float32 ...
#     l2p_flags                    (time, nj, ni) int16 ...
#     sea_surface_temperature_4um  (time, nj, ni) float32 ...
#     quality_level_4um            (time, nj, ni) float32 ...
#     sses_bias_4um                (time, nj, ni) float32 ...
#     sses_standard_deviation_4um  (time, nj, ni) float32 ...
#     wind_speed                   (time, nj, ni) float32 ...
#     dt_analysis                  (time, nj, ni) float32 ...
# Attributes:
#     Conventions:                CF-1.7, ACDD-1.3
#     title:                      MODIS Terra L2P SST
#     summary:                    Sea surface temperature retrievals produced a...
#     references:                 GHRSST Data Processing Specification v2r5
#     institution:                NASA/JPL/OBPG/RSMAS
#     history:                    MODIS L2P created at JPL PO.DAAC
#     comment:                    L2P Core without DT analysis or other ancilla...
#     license:                    GHRSST and PO.DAAC protocol allow data use as...
#     id:                         MODIS_T-JPL-L2P-v2019.0
#     naming_authority:           org.ghrsst
#     product_version:            2019.0
#     uuid:                       f6e1f61d-c4a4-4c17-8354-0c15e12d688b
#     gds_version_id:             2.0
#     netcdf_version_id:          4.1
#     date_created:               20201115T212053Z
#     file_quality_level:         3
#     spatial_resolution:         1km
#     start_time:                 20200823T030000Z
#     time_coverage_start:        20200823T030000Z
#     stop_time:                  20200823T030459Z
#     time_coverage_end:          20200823T030459Z
#     northernmost_latitude:      28.5338
#     southernmost_latitude:      7.54805
#     easternmost_longitude:      -58.1941
#     westernmost_longitude:      -84.2808
#     source:                     MODIS sea surface temperature observations fo...
#     platform:                   Terra
#     sensor:                     MODIS
#     metadata_link:              http://podaac.jpl.nasa.gov/ws/metadata/datase...
#     keywords:                   Oceans > Ocean Temperature > Sea Surface Temp...
#     keywords_vocabulary:        NASA Global Change Master Directory (GCMD) Sc...
#     standard_name_vocabulary:   NetCDF Climate and Forecast (CF) Metadata Con...
#     geospatial_lat_units:       degrees_north
#     geospatial_lat_resolution:  0.01
#     geospatial_lon_units:       degrees_east
#     geospatial_lon_resolution:  0.01
#     acknowledgment:             The MODIS L2P sea surface temperature data ar...
#     creator_name:               Ed Armstrong, JPL PO.DAAC
#     creator_email:              edward.m.armstrong@jpl.nasa.gov
#     creator_url:                http://podaac.jpl.nasa.gov
#     project:                    Group for High Resolution Sea Surface Tempera...
#     publisher_name:             The GHRSST Project Office
#     publisher_url:              http://www.ghrsst.org
#     publisher_email:            ghrsst-po@nceo.ac.uk
#     processing_level:           L2P
#     cdm_data_type:              swath
#     startDirection:             Ascending
#     endDirection:               Ascending
#     day_night_flag:             Night

# %%
ds_MODIS_shp.lon[0,0].values, ds_MODIS_shp.lat[0,0].values
ds_MODIS_shp.lon[0,0].values, ds_MODIS_shp.lat[0,0].values
# Out:
# (array(-58.19407654), array(10.53225899))

# %%
ax = plt.axes(projection=ccrs.PlateCarree())
ax.coastlines(zorder=10)

#ds_MODIS_shp.sea_surface_temperature.plot(ax=ax, transform=ccrs.PlateCarree())
ax.scatter(ds_MODIS_shp.lon, ds_MODIS_shp.lat, lw=2, c=ds_MODIS_shp.sea_surface_temperature)
plt.colorbar()
#plt.clim(-0.3, 0.3)

plt.show()

# %% [markdown]
# This file from 23 Aug 2020 intersects our shp boundary. In this case, overlap is not extensive, but it does overlap. We can confirm our search by doing the same query in the **Earthdata Search** portal mentioned at the beginning of the tutorial. https://search.earthdata.nasa.gov/search/granules?projectId=8195834861
#
# Indeed the granule returned matches the search boundary:
#
# <img align="center"
#      src="EDS_shp_granule1.png">

# %% [markdown]
# ## 5. Download after spatial and temporal selection
# Loop to download the MODIS SST files based on our search criteria (those that intersect the region of interest (defined by our shapefile here) and our period of interest.

# %%
results = response.json()['items']
urls = []
for r in results:
    for u in r['umm']['RelatedUrls']:
        if u['URL'].startswith("https://archive.podaac") and u['Type']=="GET DATA":
            urls.append(u['URL'])
urls

# %%
for u in urls:
    r = requests.get(u)
    with open(basename(u), 'wb') as f:
        f.write(r.content)

# %% [markdown]
# We now have the 33 files from our search downloaded to our local environment (computer).
#
# <img align="center"
#      src="files_download.png">
#
# ## Tutorial Summary & Discusssion
#
# We've searched for a dataset of interest that is archived in the PO.DAAC Earthdata Cloud, previewed it, selected certain data granules that matched a user-defined spatial area (by using .shp files) and temporal range, and downloaded the serach results to our local computer, from the Earthdata Cloud.
#
# From here, additional analysis can be done. In future guiding notebooks, handling of MODIS L2 SST data into analysis ready data (ARD) 'data cubes'or 'time series stacks' will also be made available, which further shows how to treat level 2 data to create level 3-like uniformly gridded L2 data to your exact specifications.
#
# And as mentioned at the beginning of the notebook, in this example we are using a shape file to search on ocean remote sensing data, although one can do this type of search on any Earthdata (DAAC) data. For example, of particular interest could be using shape files to search on terrestrial hydrology data (e.g watersheds), globally (depending on data availability of course), or other coastal regions with unique boundaries.
