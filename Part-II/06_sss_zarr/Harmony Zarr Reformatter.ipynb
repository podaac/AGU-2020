# %% [markdown]
# # Harmony Zarr Reformatter
#
# Harmony provides a service that can reformat NetCDF files as [Zarr](https://zarr.readthedocs.io/en/stable/) files accessible via the S3 API.  **The results require access to the Harmony AWS accounts using S3 credentials, so the service is not yet widely usable.**
#
# This notebook is a continuation of the [Harmony API Introduction](./Harmony%20Api%20Introduction.ipynb) and assumes familiarity with Harmony concepts and asynchronous processing in particular.

# %% [markdown]
# ## Prerequisites
#
# * gdal
# * netcdf4
# * s3fs
# * zarr
# * rasterio

# %%
#import sys
#!conda install -c conda-forge --yes --prefix {sys.prefix} netcdf4 gdal s3fs zarr xarray

# %% [markdown]
# ## Set Up AWS
#
# Now that you have Zarr links, you can access them with your AWS credentials to the Harmony account.  Obtain the credentials and make sure your default AWS account uses them.  One way to do this is to edit `~/.aws/credentials` to have the following section:
#
# ### Obtain the harmony credential
#
# got to [`https://harmony.uat.earthdata.nasa.gov/cloud-access`](https://harmony.uat.earthdata.nasa.gov/cloud-access) in a browser and you'll get a json response with a variety of fields. Fill this in below:
#
# ```
# [default]
# aws_access_key_id =
# aws_secret_access_key =
# session_token =
# ```
# Restart your Jupyter kernel after completing this step

# %% [markdown]
# ## Setup imports and Earthdata Login
#
# As with the prior notebook, we need to set up general-purpose imports and authentication

# %%
# Install prerequisite packages
#import sys
#!{sys.executable} -m pip install rasterio # Install a pip package in the current Jupyter kernel

# %%
from urllib import request, parse
from http.cookiejar import CookieJar
import getpass
import netrc
import os
import requests
import json
import pprint
from osgeo import gdal
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import rasterio
from rasterio.plot import show
import numpy as np
import os
import time
# %matplotlib inline

# %%
def setup_earthdata_login_auth(endpoint):
    """
    Set up the request library so that it authenticates against the given Earthdata Login
    endpoint and is able to track cookies between requests.  This looks in the .netrc file 
    first and if no credentials are found, it prompts for them.

    Valid endpoints include:
        uat.urs.earthdata.nasa.gov - Earthdata Login UAT (Harmony's current default)
        urs.earthdata.nasa.gov - Earthdata Login production
    """
    try:
        username, _, password = netrc.netrc().authenticators(endpoint)
    except (FileNotFoundError, TypeError):
        # FileNotFound = There's no .netrc file
        # TypeError = The endpoint isn't in the netrc file, causing the above to try unpacking None
        print('Please provide your Earthdata Login credentials to allow data access')
        print('Your credentials will only be passed to %s and will not be exposed in Jupyter' % (endpoint))
        username = input('Username:')
        password = getpass.getpass()

    manager = request.HTTPPasswordMgrWithDefaultRealm()
    manager.add_password(None, endpoint, username, password)
    auth = request.HTTPBasicAuthHandler(manager)

    jar = CookieJar()
    processor = request.HTTPCookieProcessor(jar)
    opener = request.build_opener(auth, processor)
    request.install_opener(opener)

# %%
#setup_earthdata_login_auth('uat.urs.earthdata.nasa.gov')
setup_earthdata_login_auth('urs.earthdata.nasa.gov')
# Out:
# Please provide your Earthdata Login credentials to allow data access
# Your credentials will only be passed to urs.earthdata.nasa.gov and will not be exposed in Jupyter
# Username:jmcnelis
# ········

# %% [markdown]
# ## Access files as zarr
#
# All zarr reformatting requests produce asynchronous results that point to s3 locations in the Harmony account.
#
# To request zarr, pass `format=application/x-zarr` as a paramter the coverages service.  The following fetches data from a test collection as zarr.

# %%
#harmony_root = 'https://harmony.uat.earthdata.nasa.gov'
harmony_root = 'https://harmony.earthdata.nasa.gov'
#jobID = 'd25863c4-9ca4-4711-94c5-1eedfa9c6c0c'

# %%
# If you have a job ID you'd like to explore instead of re-running this command,
# enter it as the 'jobID' in the above cell and skip to 'Query for the job status and links'

harmony_collection_id='C1940468263-POCLOUD'  # PRODUCTION
#harmony_collection_id='C1234410736-POCLOUD'  # UAT
asyncConfig = {
    'collection_id': harmony_collection_id,
    'ogc-api-coverages_version': '1.0.0',
    'variable': 'all',
    'format': 'application/x-zarr',
    'start': '2020-01-01T00:00:00.000Z',
    'stop':'2020-01-02T00:00:00.000Z'
}

async_url = harmony_root+'/{collection_id}/ogc-api-coverages/{ogc-api-coverages_version}/collections/{variable}/coverage/rangeset?format={format}&subset=time("{start}":"{stop}")'.format(**asyncConfig)
print('Request URL', async_url)
async_response = request.urlopen(async_url)
async_results = async_response.read()
async_json = json.loads(async_results)
pprint.pprint(async_json)
# Out:
# Request URL https://harmony.earthdata.nasa.gov/C1940468263-POCLOUD/ogc-api-coverages/1.0.0/collections/all/coverage/rangeset?format=application/x-zarr&subset=time("2020-01-01T00:00:00.000Z":"2020-01-02T00:00:00.000Z")
# {'createdAt': '2020-11-18T19:43:10.943Z',
#  'links': [{'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/SMAP_RSS_L3_SSS_SMI_8DAY-RUNNINGMEAN_V4/RSS_smap_SSS_L3_8day_running_2019_362_FNL_v04.0.nc',
#             'rel': 'data',
#             'title': 'G1950510297-POCLOUD'},
#            {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/SMAP_RSS_L3_SSS_SMI_8DAY-RUNNINGMEAN_V4/RSS_smap_SSS_L3_8day_running_2019_363_FNL_v04.0.nc',
#             'rel': 'data',
#             'title': 'G1950510302-POCLOUD'},
#            {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/SMAP_RSS_L3_SSS_SMI_8DAY-RUNNINGMEAN_V4/RSS_smap_SSS_L3_8day_running_2019_364_FNL_v04.0.nc',
#             'rel': 'data',
#             'title': 'G1950510206-POCLOUD'},
#            {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/SMAP_RSS_L3_SSS_SMI_8DAY-RUNNINGMEAN_V4/RSS_smap_SSS_L3_8day_running_2019_365_FNL_v04.0.nc',
#             'rel': 'data',
#             'title': 'G1950510203-POCLOUD'},
#            {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/SMAP_RSS_L3_SSS_SMI_8DAY-RUNNINGMEAN_V4/RSS_smap_SSS_L3_8day_running_2020_001_FNL_v04.0.nc',
#             'rel': 'data',
#             'title': 'G1950510304-POCLOUD'},
#            {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/SMAP_RSS_L3_SSS_SMI_8DAY-RUNNINGMEAN_V4/RSS_smap_SSS_L3_8day_running_2020_002_FNL_v04.0.nc',
#             'rel': 'data',
#             'title': 'G1950510296-POCLOUD'},
#            {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/SMAP_RSS_L3_SSS_SMI_8DAY-RUNNINGMEAN_V4/RSS_smap_SSS_L3_8day_running_2020_003_FNL_v04.0.nc',
#             'rel': 'data',
#             'title': 'G1950510295-POCLOUD'},
#            {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/SMAP_RSS_L3_SSS_SMI_8DAY-RUNNINGMEAN_V4/RSS_smap_SSS_L3_8day_running_2020_004_FNL_v04.0.nc',
#             'rel': 'data',
#             'title': 'G1950510298-POCLOUD'},
#            {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/SMAP_RSS_L3_SSS_SMI_8DAY-RUNNINGMEAN_V4/RSS_smap_SSS_L3_8day_running_2020_005_FNL_v04.0.nc',
#             'rel': 'data',
#             'title': 'G1950510305-POCLOUD'}],
#  'message': 'Returning direct download links because no operations can be '
#             'performed on C1940468263-POCLOUD.',
#  'progress': 100,
#  'request': 'https://harmony.earthdata.nasa.gov/C1940468263-POCLOUD/ogc-api-coverages/1.0.0/collections/all/coverage/rangeset?format=application%2Fx-zarr&subset=time(%222020-01-01T00%3A00%3A00.000Z%22%3A%222020-01-02T00%3A00%3A00.000Z%22)',
#  'status': 'successful',
#  'updatedAt': '2020-11-18T19:43:10.943Z',
#  'username': 'jmcnelis'}

# %%
async_json
# Out:
# {'username': 'jmcnelis',
#  'status': 'successful',
#  'message': 'Returning direct download links because no operations can be performed on C1940468263-POCLOUD.',
#  'progress': 100,
#  'createdAt': '2020-11-18T19:43:10.943Z',
#  'updatedAt': '2020-11-18T19:43:10.943Z',
#  'links': [{'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/SMAP_RSS_L3_SSS_SMI_8DAY-RUNNINGMEAN_V4/RSS_smap_SSS_L3_8day_running_2019_362_FNL_v04.0.nc',
#    'title': 'G1950510297-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/SMAP_RSS_L3_SSS_SMI_8DAY-RUNNINGMEAN_V4/RSS_smap_SSS_L3_8day_running_2019_363_FNL_v04.0.nc',
#    'title': 'G1950510302-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/SMAP_RSS_L3_SSS_SMI_8DAY-RUNNINGMEAN_V4/RSS_smap_SSS_L3_8day_running_2019_364_FNL_v04.0.nc',
#    'title': 'G1950510206-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/SMAP_RSS_L3_SSS_SMI_8DAY-RUNNINGMEAN_V4/RSS_smap_SSS_L3_8day_running_2019_365_FNL_v04.0.nc',
#    'title': 'G1950510203-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/SMAP_RSS_L3_SSS_SMI_8DAY-RUNNINGMEAN_V4/RSS_smap_SSS_L3_8day_running_2020_001_FNL_v04.0.nc',
#    'title': 'G1950510304-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/SMAP_RSS_L3_SSS_SMI_8DAY-RUNNINGMEAN_V4/RSS_smap_SSS_L3_8day_running_2020_002_FNL_v04.0.nc',
#    'title': 'G1950510296-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/SMAP_RSS_L3_SSS_SMI_8DAY-RUNNINGMEAN_V4/RSS_smap_SSS_L3_8day_running_2020_003_FNL_v04.0.nc',
#    'title': 'G1950510295-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/SMAP_RSS_L3_SSS_SMI_8DAY-RUNNINGMEAN_V4/RSS_smap_SSS_L3_8day_running_2020_004_FNL_v04.0.nc',
#    'title': 'G1950510298-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/SMAP_RSS_L3_SSS_SMI_8DAY-RUNNINGMEAN_V4/RSS_smap_SSS_L3_8day_running_2020_005_FNL_v04.0.nc',
#    'title': 'G1950510305-POCLOUD',
#    'rel': 'data'}],
#  'request': 'https://harmony.earthdata.nasa.gov/C1940468263-POCLOUD/ogc-api-coverages/1.0.0/collections/all/coverage/rangeset?format=application%2Fx-zarr&subset=time(%222020-01-01T00%3A00%3A00.000Z%22%3A%222020-01-02T00%3A00%3A00.000Z%22)'}

# %% [markdown]
# Wait for the job to finish using the loop we demonstrated in the API Introduction notebook

# %%
jobID = async_json['jobID']
jobID
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-d85a8123d79d> in <module>
# ----> 1 jobID = async_json['jobID']
#       2 jobID
#
# KeyError: 'jobID'

# %% [markdown]
# ## Find compatible collections on PROD

# %%
colls = {}
coll_request = "https://cmr.earthdata.nasa.gov/search/collections.umm_json?provider=POCLOUD&pretty=true&token=F1001701-E043-F2FC-C347-6841585B6624"
coll_records = requests.get(coll_request).json()
for c in coll_records['items']:
    colls.update({c['umm']['ShortName']: c['meta']['concept-id']})
colls
# Out:
# {'MODIS_A-JPL-L2P-v2019.0': 'C1940473819-POCLOUD',
#  'MODIS_T-JPL-L2P-v2019.0': 'C1940475563-POCLOUD',
#  'MERGED_TP_J1_OSTM_OST_CYCLES_V42': 'C1940466008-POCLOUD',
#  'JASON-1_L2_OST_GPR_E': 'C1940471193-POCLOUD',
#  'JASON-1_L2_OST_GPN_E': 'C1940470304-POCLOUD',
#  'JASON-1_L2_OST_GPS_E': 'C1940472420-POCLOUD',
#  'TELLUS_GRAC-GRFO_MASCON_CRI_GRID_RL06_V2': 'C1938032626-POCLOUD',
#  'DPUB_LX_DUMMY_COLLECTION_V1.0': 'C1955420965-POCLOUD',
#  'SMAP_RSS_L3_SSS_SMI_8DAY-RUNNINGMEAN_V4': 'C1940468263-POCLOUD'}

# %%
def start_job(harmony_collection_id: str):
    
    # If you have a job ID you'd like to explore instead of re-running this command,
    # enter it as the 'jobID' in the above cell and skip to 'Query for the job status and links'

    #harmony_collection_id='C1940468263-POCLOUD'  # PRODUCTION
    #harmony_collection_id='C1234410736-POCLOUD'  # UAT
    asyncConfig = {
        'collection_id': harmony_collection_id,
        'ogc-api-coverages_version': '1.0.0',
        'variable': 'all',
        'format': 'application/x-zarr',
        'start': '2020-01-01T00:00:00.000Z',
        'stop':'2020-01-02T00:00:00.000Z'
    }

    async_url = harmony_root+'/{collection_id}/ogc-api-coverages/{ogc-api-coverages_version}/collections/{variable}/coverage/rangeset?format={format}&subset=time("{start}":"{stop}")'.format(**asyncConfig)
    print('Request URL', async_url)
    async_response = request.urlopen(async_url)
    async_results = async_response.read()
    async_json = json.loads(async_results)
    return async_json
    

test_all_collections_jobs = {}
for name, ccid in colls.items():
#     if name=="MERGED_TP_J1_OSTM_OST_CYCLES_V42":
#         pass
#     if name.startswith("JASON-1"):
#         pass
    try:
        test_all_collections_jobs[name] = start_job(ccid)
    except Exception as e:
        test_all_collections_jobs[name] = e.msg
        print(f"FAIL: {name}")
# Out:
# Request URL https://harmony.earthdata.nasa.gov/C1940473819-POCLOUD/ogc-api-coverages/1.0.0/collections/all/coverage/rangeset?format=application/x-zarr&subset=time("2020-01-01T00:00:00.000Z":"2020-01-02T00:00:00.000Z")
# Request URL https://harmony.earthdata.nasa.gov/C1940475563-POCLOUD/ogc-api-coverages/1.0.0/collections/all/coverage/rangeset?format=application/x-zarr&subset=time("2020-01-01T00:00:00.000Z":"2020-01-02T00:00:00.000Z")
# Request URL https://harmony.earthdata.nasa.gov/C1940466008-POCLOUD/ogc-api-coverages/1.0.0/collections/all/coverage/rangeset?format=application/x-zarr&subset=time("2020-01-01T00:00:00.000Z":"2020-01-02T00:00:00.000Z")
# FAIL: MERGED_TP_J1_OSTM_OST_CYCLES_V42
# Request URL https://harmony.earthdata.nasa.gov/C1940471193-POCLOUD/ogc-api-coverages/1.0.0/collections/all/coverage/rangeset?format=application/x-zarr&subset=time("2020-01-01T00:00:00.000Z":"2020-01-02T00:00:00.000Z")
# FAIL: JASON-1_L2_OST_GPR_E
# Request URL https://harmony.earthdata.nasa.gov/C1940470304-POCLOUD/ogc-api-coverages/1.0.0/collections/all/coverage/rangeset?format=application/x-zarr&subset=time("2020-01-01T00:00:00.000Z":"2020-01-02T00:00:00.000Z")
# FAIL: JASON-1_L2_OST_GPN_E
# Request URL https://harmony.earthdata.nasa.gov/C1940472420-POCLOUD/ogc-api-coverages/1.0.0/collections/all/coverage/rangeset?format=application/x-zarr&subset=time("2020-01-01T00:00:00.000Z":"2020-01-02T00:00:00.000Z")
# FAIL: JASON-1_L2_OST_GPS_E
# Request URL https://harmony.earthdata.nasa.gov/C1938032626-POCLOUD/ogc-api-coverages/1.0.0/collections/all/coverage/rangeset?format=application/x-zarr&subset=time("2020-01-01T00:00:00.000Z":"2020-01-02T00:00:00.000Z")
# Request URL https://harmony.earthdata.nasa.gov/C1955420965-POCLOUD/ogc-api-coverages/1.0.0/collections/all/coverage/rangeset?format=application/x-zarr&subset=time("2020-01-01T00:00:00.000Z":"2020-01-02T00:00:00.000Z")
# FAIL: DPUB_LX_DUMMY_COLLECTION_V1.0
# Request URL https://harmony.earthdata.nasa.gov/C1940468263-POCLOUD/ogc-api-coverages/1.0.0/collections/all/coverage/rangeset?format=application/x-zarr&subset=time("2020-01-01T00:00:00.000Z":"2020-01-02T00:00:00.000Z")

# %%
test_all_collections_jobs.keys()
# Out:
# dict_keys(['MODIS_A-JPL-L2P-v2019.0', 'MODIS_T-JPL-L2P-v2019.0', 'MERGED_TP_J1_OSTM_OST_CYCLES_V42', 'JASON-1_L2_OST_GPR_E', 'JASON-1_L2_OST_GPN_E', 'JASON-1_L2_OST_GPS_E', 'TELLUS_GRAC-GRFO_MASCON_CRI_GRID_RL06_V2', 'DPUB_LX_DUMMY_COLLECTION_V1.0', 'SMAP_RSS_L3_SSS_SMI_8DAY-RUNNINGMEAN_V4'])

# %%
for k, v in test_all_collections_jobs.items():
    print(k)
    if type(v) is str:
        print(v)
    else:
        print(v['message'])
    print("#"*60)
# Out:
# MODIS_A-JPL-L2P-v2019.0
# Returning direct download links because the requested combination of operations: reformatting to application/x-zarr on C1940473819-POCLOUD is unsupported. CMR query identified 333 granules, but the request has been limited to process only the first 200 granules because of system constraints.
# ############################################################
# MODIS_T-JPL-L2P-v2019.0
# Returning direct download links because the requested combination of operations: reformatting to application/x-zarr on C1940475563-POCLOUD is unsupported. CMR query identified 333 granules, but the request has been limited to process only the first 200 granules because of system constraints.
# ############################################################
# MERGED_TP_J1_OSTM_OST_CYCLES_V42
# Bad Request
# ############################################################
# JASON-1_L2_OST_GPR_E
# Bad Request
# ############################################################
# JASON-1_L2_OST_GPN_E
# Bad Request
# ############################################################
# JASON-1_L2_OST_GPS_E
# Bad Request
# ############################################################
# TELLUS_GRAC-GRFO_MASCON_CRI_GRID_RL06_V2
# Returning direct download links because no operations can be performed on C1938032626-POCLOUD.
# ############################################################
# DPUB_LX_DUMMY_COLLECTION_V1.0
# Bad Request
# ############################################################
# SMAP_RSS_L3_SSS_SMI_8DAY-RUNNINGMEAN_V4
# Returning direct download links because no operations can be performed on C1940468263-POCLOUD.
# ############################################################

# %%
test_all_collections_jobs['MODIS_T-JPL-L2P-v2019.0']
# Out:
# {'username': 'jmcnelis',
#  'status': 'successful',
#  'message': 'Returning direct download links because the requested combination of operations: reformatting to application/x-zarr on C1940475563-POCLOUD is unsupported. CMR query identified 333 granules, but the request has been limited to process only the first 200 granules because of system constraints.',
#  'progress': 100,
#  'createdAt': '2020-11-18T19:49:57.595Z',
#  'updatedAt': '2020-11-18T19:49:57.595Z',
#  'links': [{'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101000001-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968355689-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101000501-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968137005-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101001001-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968266043-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101001500-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968178413-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101002000-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968165884-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101002500-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968273795-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101002500-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968386288-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101003001-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968311212-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101003501-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968291094-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101004001-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968287291-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101004501-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968313651-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101005001-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968351223-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101005501-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968327461-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101010001-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968209359-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101010500-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968191900-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101011000-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968309644-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101011500-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968282561-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101011500-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968373691-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101012000-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968187430-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101012501-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968301124-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101013001-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968171962-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101013501-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968251843-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101014001-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968194971-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101014501-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968287721-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101015001-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968175950-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101015501-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968283272-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101020000-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968151454-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101020500-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968158047-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101020500-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968379819-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101021000-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968250311-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101021501-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968398907-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101022001-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968380946-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101022501-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968138243-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101023001-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968355332-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101023501-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968218900-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101024001-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968240674-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101024501-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968376572-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101025000-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968234708-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101025500-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968149993-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101025500-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968191378-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101030000-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968283427-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101030500-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968383138-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101031001-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968267911-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101031501-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968177940-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101032001-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968185577-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101032501-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968260553-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101033001-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968184001-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101033501-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968362401-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101034001-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968142526-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101034001-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968207723-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101034500-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968227312-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101034500-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968231391-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101035000-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968245633-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101035500-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968264191-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101040001-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968276612-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101040501-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968172973-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101041001-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968139753-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101041501-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968257076-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101042001-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968219147-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101042501-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968279667-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101043001-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968135839-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101043001-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968171894-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101043500-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968165508-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101043500-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968214605-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101044000-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968154492-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101044500-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968307923-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101045000-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968250527-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101045501-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968184646-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101050001-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968138824-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101050501-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968386219-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101051001-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968149289-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101051501-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968138769-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101052001-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968156699-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101052001-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968376971-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101052501-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968352057-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101052501-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968367065-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101053000-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968251848-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101053500-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968269626-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101054000-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968354719-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101054501-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968239103-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101055001-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968268424-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101055501-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968322704-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101060001-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968240508-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101060501-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968300479-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101061001-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968224568-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101061001-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968386450-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101061501-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968177040-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101061501-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968369316-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101062000-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968353995-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101062500-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968315421-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101063000-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968319756-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101063500-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968391342-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101064001-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968314535-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101064501-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968310719-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101065001-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968397734-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101065501-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968223713-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101070001-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968247023-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101070001-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968395524-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101070501-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968291304-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101070501-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968365764-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101071001-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968290814-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101071500-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968364052-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101072000-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968362152-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101072500-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968260930-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101073001-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968138327-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101073501-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968336409-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101074001-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968302515-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101074501-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968384970-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101075001-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968136870-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101075001-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968159782-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101075501-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968330502-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101080001-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968189233-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101080501-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968228304-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101081000-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968284657-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101081500-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968373238-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101082000-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968189023-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101082501-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968231600-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101083001-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968308070-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101083501-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968228270-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101084001-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968144817-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101084001-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968231659-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101084501-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968264806-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101085001-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968157072-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101085501-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968287652-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101090000-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968341504-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101090500-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968350827-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101091000-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968325735-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101091500-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968318008-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101092001-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968290402-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101092501-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968384012-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101093001-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968220749-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101093001-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968360888-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101093501-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968180900-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101094001-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968352511-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101094501-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968312561-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101095001-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968278159-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101095500-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968290175-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101100000-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968237584-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101100500-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968144158-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101101001-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968231768-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101101501-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968308434-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101102001-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968359389-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101102001-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968397429-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101102501-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968209978-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101103001-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968391655-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101103501-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968354144-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101104001-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968157170-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101104500-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968340539-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101105000-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968312100-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101105500-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968144272-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101110000-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968164398-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101110501-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968212505-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101110501-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968267945-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101111001-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968276711-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101111001-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968282601-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101111501-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968311823-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101112001-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968375265-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101112501-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968353843-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101113001-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968289127-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101113501-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968173107-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101114000-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968258184-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101114500-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968295515-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101115000-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968308433-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101115501-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968153463-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101115501-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968241977-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101120001-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968241379-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101120001-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968361858-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101120501-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968300128-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101121001-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968202917-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101121501-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968212977-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101122001-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968280834-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101122501-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968171508-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101123000-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968162801-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101123500-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968177497-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101124000-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968380164-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101124500-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968191508-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101124500-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968393846-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101125001-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968171778-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101125001-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968230017-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101125501-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968192498-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101130001-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968185238-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101130501-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968208837-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101131001-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968165760-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101131501-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968282043-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101132001-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968187235-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101132500-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968387034-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101133000-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968276816-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101133500-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968287725-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101133500-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968374146-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101134001-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968151038-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101134001-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968239890-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101134501-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968245521-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101135001-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968146098-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101135501-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968304385-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101140001-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968388615-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101140501-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968174277-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101141001-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968335170-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101141500-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968135049-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101142000-JPL-L2P_GHRSST-SSTskin-MODIS_T-D-v02.0-fv01.0.nc',
#    'title': 'G1968234507-POCLOUD',
#    'rel': 'data'},
#   {'href': 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/MODIS_T-JPL-L2P-v2019.0/20200101142500-JPL-L2P_GHRSST-SSTskin-MODIS_T-N-v02.0-fv01.0.nc',
#    'title': 'G1968186395-POCLOUD',
#    'rel': 'data'}],
#  'request': 'https://harmony.earthdata.nasa.gov/C1940475563-POCLOUD/ogc-api-coverages/1.0.0/collections/all/coverage/rangeset?format=application%2Fx-zarr&subset=time(%222020-01-01T00%3A00%3A00.000Z%22%3A%222020-01-02T00%3A00%3A00.000Z%22)'}

# %% [markdown]
# ### Query for the job status and links

# %%
job_url = harmony_root + '/jobs/' + jobID

#Continue loop while request is still processing
while True:
    loop_response = request.urlopen(job_url)
    loop_results = loop_response.read()
    job_json = json.loads(loop_results)
    if job_json['status'] != 'running':
        break
    print('Job status is running. Progress is ', job_json['progress'], '%. Trying again.')
    time.sleep(5)

links = []
if job_json['status'] == 'successful' and job_json['progress'] == 100:
    print('Job progress is 100%. Output links printed below:')
    links = [link['href'] for link in job_json['links']]
    print('\n'.join(links))
# Out:
# Job progress is 100%. Output links printed below:
# https://harmony.uat.earthdata.nasa.gov/jobs/76787428-5c72-4b06-8c2f-d160629515fa
# https://harmony.uat.earthdata.nasa.gov/stac/76787428-5c72-4b06-8c2f-d160629515fa/
# https://harmony.uat.earthdata.nasa.gov/cloud-access.sh
# https://harmony.uat.earthdata.nasa.gov/cloud-access
# s3://harmony-uat-staging/public/harmony/netcdf-to-zarr/fb497626-9597-4cb2-9f40-e88443c56bbc/
# s3://harmony-uat-staging/public/harmony/netcdf-to-zarr/fb497626-9597-4cb2-9f40-e88443c56bbc/RSS_smap_SSS_L3_8day_running_2019_362_FNL_v04.0.zarr
# s3://harmony-uat-staging/public/harmony/netcdf-to-zarr/fb497626-9597-4cb2-9f40-e88443c56bbc/RSS_smap_SSS_L3_8day_running_2019_363_FNL_v04.0.zarr
# s3://harmony-uat-staging/public/harmony/netcdf-to-zarr/fb497626-9597-4cb2-9f40-e88443c56bbc/RSS_smap_SSS_L3_8day_running_2019_364_FNL_v04.0.zarr
# s3://harmony-uat-staging/public/harmony/netcdf-to-zarr/fb497626-9597-4cb2-9f40-e88443c56bbc/RSS_smap_SSS_L3_8day_running_2019_365_FNL_v04.0.zarr
# s3://harmony-uat-staging/public/harmony/netcdf-to-zarr/fb497626-9597-4cb2-9f40-e88443c56bbc/RSS_smap_SSS_L3_8day_running_2020_001_FNL_v04.0.zarr
# s3://harmony-uat-staging/public/harmony/netcdf-to-zarr/fb497626-9597-4cb2-9f40-e88443c56bbc/RSS_smap_SSS_L3_8day_running_2020_002_FNL_v04.0.zarr
# s3://harmony-uat-staging/public/harmony/netcdf-to-zarr/fb497626-9597-4cb2-9f40-e88443c56bbc/RSS_smap_SSS_L3_8day_running_2020_003_FNL_v04.0.zarr
# s3://harmony-uat-staging/public/harmony/netcdf-to-zarr/fb497626-9597-4cb2-9f40-e88443c56bbc/RSS_smap_SSS_L3_8day_running_2020_004_FNL_v04.0.zarr
# s3://harmony-uat-staging/public/harmony/netcdf-to-zarr/fb497626-9597-4cb2-9f40-e88443c56bbc/RSS_smap_SSS_L3_8day_running_2020_005_FNL_v04.0.zarr

# %% [markdown]
# Use the keys at the `cloud_access` links above to access the S3 bucket:

# %% [markdown]
# ```sh
# #!/bin/sh
# # Source this file to set keys to access Harmony S3 outputs within the us-west-2 region.
# # Keys will expire on Wed, 18 Nov 2020 15:15:50 GMT
# export AWS_ACCESS_KEY_ID='ASIAX72DTRJ6ZVANYSXB'
# export AWS_SECRET_ACCESS_KEY='Qay2hNMrilixUxc5zr+wUYD7ZtQN+v/8s8Rhwfse'
# export AWS_SESSION_TOKEN=''
# ```

# %% [markdown]
# ## Open and explore the Zarr file
#
# This portion of the code must be run from a node in US-WEST-2 to get atc

# %%
#help(s3fs.S3FileSystem)
#access = requests.get("https://harmony.uat.earthdata.nasa.gov/cloud-access").json()
#access

# %%
_keys = {
    "AccessKeyId":"ASIAX72DTRJ6ZPRCFXHU",
    "SecretAccessKey":"+bp7rB+644QFUA4CnbY1ccoRjm564KDLfdkQVLf4",
    "SessionToken":"",
     #"Expiration":"2020-11-18T15:15:37.000Z"}
}

# %%
import s3fs
import zarr
import botocore

#client_session = botocore.session.Session(profile='default')

#fs = s3fs.S3FileSystem(region_name='us-west-2')
fs = s3fs.S3FileSystem(
    key=_keys['AccessKeyId'],
    secret=_keys['SecretAccessKey'],
    token=_keys['SessionToken'],
    client_kwargs={'region_name':'us-west-2'},
)

#print(fs.__version__)
store = fs.get_mapper(root=links[6], check=False)

zarr_file = zarr.open(store)

# %% [markdown]
# Explore the contents of the Zarr file

# %%
print(zarr_file.tree())
print(zarr_file.sss_smap.info)
# Out:
# /
#  ├── fland (720, 1440) float32
#  ├── gice (720, 1440) float32
#  ├── gland (720, 1440) float32
#  ├── lat (720,) float32
#  ├── lon (1440,) float32
#  ├── nobs (720, 1440) int32
#  ├── nobs_40km (720, 1440) int32
#  ├── sss_ref (720, 1440) float32
#  ├── sss_smap (720, 1440) float32
#  ├── sss_smap_40km (720, 1440) float32
#  ├── sss_smap_uncertainty (720, 1440) float32
#  ├── surtep (720, 1440) float32
#  └── time (1,) float64
# Name               : /sss_smap
# Type               : zarr.core.Array
# Data type          : float32
# Shape              : (720, 1440)
# Chunk shape        : (720, 1440)
# Order              : C
# Read-only          : False
# Compressor         : Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, blocksize=0)
# Store type         : fsspec.mapping.FSMap
# No. bytes          : 4147200 (4.0M)
# Chunks initialized : 1/1

# %%
plt.imshow(zarr_file['gice']);
plt.colorbar()

#flip the image
ax = plt.gca()
ax.set_ylim(ax.get_ylim()[::-1])
# Out:
# (-0.5, 719.5)

# %% [markdown]
# ## (Optional) Import the zarr into xarray and plot

# %%
import xarray as xr
ds_zarr = xr.open_zarr(store)
print(ds_zarr['sss_smap'])
# Out:
# <xarray.DataArray 'sss_smap' (lat: 720, lon: 1440)>
# [1036800 values with dtype=float32]
# Coordinates:
#   * lat      (lat) float32 -89.875 -89.625 -89.375 ... 89.375 89.625 89.875
#   * lon      (lon) float32 0.125 0.375 0.625 0.875 ... 359.375 359.625 359.875
# Attributes:
#     long_name:      SMAP sea surface salinity smoothed to approx 70km resolution
#     standard_name:  sea_surface_salinity
#     units:          1e-3
#     valid_max:      45.0
#     valid_min:      0.0

# %%
ds_zarr['sss_smap'].where(ds_zarr['sss_smap'] > 0).plot()
